# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# DATA COLLECTION

# %% [markdown]
# 1. Datos de Yahoo Finance

# %%
sp500 = yf.Ticker("^GSPC")
gold = yf.Ticker("^GC=F")
oil= yf.Ticker("CL=F")
brent= yf.Ticker("BZ=F")

# %% [markdown]
# Gold no existe. El ticker no baja ninguna información. Lo sustituyo por la volatilidad del mercado de oro que se descarga de los datos de la FED de St. Louis.

# %% [markdown]
# Para el Sp500 utilizo los datos a partir del año 2000, ya que en años anteriores la composición por industria del SP500 era bastante diferente. A partir de ese año hay importnate participación del sector teconología. Hago lo mismo para las otras variables

# %%
start_date = '2000-01-01'
end_date = '2024-04-30'

sp500 = sp500.history(period="max")
sp500 =sp500.loc[start_date:end_date].copy ()
oil = oil.history(period="max")
oil = oil.loc[start_date:end_date].copy ()
brent = brent.history(period="max") 
brent = brent.loc[start_date:end_date:].copy ()

# %%
sp500.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-01-03 00:00:00-05:00  1469.250000  1478.000000  1438.359985  1455.219971
# 2000-01-04 00:00:00-05:00  1455.219971  1455.219971  1397.430054  1399.420044
# 2000-01-05 00:00:00-05:00  1399.420044  1413.270020  1377.680054  1402.109985
# 2000-01-06 00:00:00-05:00  1402.109985  1411.900024  1392.099976  1403.449951
# 2000-01-07 00:00:00-05:00  1403.449951  1441.469971  1400.729980  1441.469971
#
#                                Volume  Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-05:00   931800000        0.0           0.0
# 2000-01-04 00:00:00-05:00  1009000000        0.0           0.0
# 2000-01-05 00:00:00-05:00  1085500000        0.0           0.0
# 2000-01-06 00:00:00-05:00  1092300000        0.0           0.0
# 2000-01-07 00:00:00-05:00  1225200000        0.0           0.0

# %%
#Remueve las columans que no necesito
sp500 = sp500.drop(columns=['Dividends', 'Stock Splits'])
sp500.index= sp500.index.tz_localize(None) # remove timezone porque tengo otras variables que no la tienen. para uniformar

# %%
#Guarda el dataset en un archivo csv   
sp500.to_csv('sp500.csv', index=True)

# %%
#Hace lo mismo con el resto de los activos
oil = oil.drop(columns=['Dividends', 'Stock Splits', 'Open', 'High', 'Low', 'Volume'])
oil.index= oil.index.tz_localize(None) # remove timezone
oil.head()
# Out:
#                 Close
# Date
# 2000-08-23  32.049999
# 2000-08-24  31.629999
# 2000-08-25  32.049999
# 2000-08-28  32.869999
# 2000-08-29  32.720001

# %%
# Renombr< la columna 'Close' a 'Close_oil' en el DataFrame 'oil' para que no se confunda con la del S&P 500
oil.rename(columns={'Close': 'Close_oil'}, inplace=True)

# Muestra las primeras filas para verificar el cambio
print(oil.head())
# Out:
#             Close_oil
# Date
# 2000-08-23  32.049999
# 2000-08-24  31.629999
# 2000-08-25  32.049999
# 2000-08-28  32.869999
# 2000-08-29  32.720001

# %% [markdown]
# 2. Datos de FRED (Banco de la Reserva Federal de St. Louis) -
#
# Información económica diaria y que refleja expectativas del mercado. Como no existen variables fundamentales diarias relacionadas con el índice,
# incluyo variables diarias del mercado que reflejen el sentimiento de la evolución de la economía, lo cual afecta consecuentemente la evolución de las empresas y su valor.
# Las variables macro y las fundamentales en general no suelen ser diarias.

# %%
import requests


# FRED API endpoint
url = "https://api.stlouisfed.org/fred/series/observations"

# List of series IDs to be downloaded
# CREDIT RISK AND RISK APPETITE VARIABLES # OJO --->>>> Estas variables miden el riesgo de crédito y el apetito por el riesgo de los inversores 

# DAAA = Moody's Seasoned Aaa Corporate Bond Yield
# AAA10Y = Moody's Seasoned Aaa Corporate Bond Yield Relative to Yield on 10-Year Treasury Constant Maturity
# DBAA = Moody's Seasoned Baa Corporate Bond Yield
# BAA10Y = Moody's Seasoned Baa Corporate Bond Yield Relative to Yield on 10-Year Treasury Constant Maturity
# BAMLH0A0HYM2 = ICE BofA US High Yield Index Option-Adjusted Spread 
# BAMLH0A2HYB = ICE BofA Single-B US High Yield Index Option-Adjusted Spread 
# BAMLH0A3HYC = ICE BofA CCC & Lower US High Yield Index Option-Adjusted Spread
# BAMLHE00EHYIOAS = ICE BofA Euro High Yield Index Option-Adjusted Spread -  

# INTEREST RATE VARIABLES
#OJO --->>>> Esta variables miden el cambio en las expectativas de inflación y los movimientos de tasas de interés

# T10Y2Y = 10-Year Treasury Constant Maturity Minus 2-Year Treasury Constant Maturity
# T10Y3M = 10-Year Treasury Constant Maturity Minus 3-Month Treasury Constant Maturity  
# T5YIE = 5-Year Breakeven Inflation Rate (Expected Inflation Rate) - 5-Year 

# EXCHANGE RATES Vs main commercial partners for the U.S.
# DEXUSEU = U.S. Dollars to Euro Spot Exchange Rate - value of one U.S. Dollar in Euros
# DEXCHUS = Chinese Yuan Renminbi to U.S. Dollar Spot Exchange Rate - value of one Chinese Yuan Renminbi in U.S. Dollars
# DEXCAUS = Canadian Dollars to U.S. Dollar Spot Exchange Rate - value of one Canadian Dollar in U.S. Dollars
# DEXMXUS= Mexican Pesos to U.S. Dollar Spot Exchange Rate - value of one Mexican Peso in U.S. Dollars

# VOLATILITY INDECES (MARKET EXPECTATION OF NEAR TERM VOLATILITY)
# VIXCLS = CBOE Volatility Index - VIX measures market expectation of near term volatility conveyed by stock index option prices.
#(GVZCLS)= CBOE Gold ETF Volatility Index 

series_ids = ['DAAA','AAA10Y','DBAA','BAA10Y','BAMLH0A0HYM2','BAMLH0A2HYB','BAMLH0A3HYC','BAMLHE00EHYIOAS','T10Y2Y','T10Y3M','T5YIE','DEXUSEU','DEXCHUS','DEXCAUS','DEXMXUS','VIXCLS','GVZCLS']

# Your FRED API key
api_key = '7de04d83472c6affd4e0a1505211d3b9'

# Initialize an empty dictionary to store DataFrames
dfs = {}

# Loop through each series ID
for series_id in series_ids:
    # API parameters
    params = {
        'series_id': series_id,
        'api_key': api_key,
        'file_type': 'json',
    }
    
    # Make the API request
    response = requests.get(url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the response to JSON
        data = response.json()
        # Extract data for DataFrame
        dates = [item['date'] for item in data['observations']]
        values = [item['value'] for item in data['observations']]
        # Create DataFrame and convert types
        temp_df = pd.DataFrame({'Date': dates, series_id: values})
        temp_df['Date'] = pd.to_datetime(temp_df['Date'])
        temp_df[series_id] = pd.to_numeric(temp_df[series_id], errors='coerce')
        # Add the DataFrame to the dictionary
        dfs[series_id] = temp_df.set_index('Date')
    else:
        print(f"Failed to retrieve data for {series_id}: {response.status_code}")

# Combine all the series DataFrames into one DataFrame 
macroeconomic_df = pd.concat(dfs.values(), axis=1)

# %% [markdown]
# 3. Uno los dataframes

# %%
# Unir macroeconomic_df con sp500 basado en sus índices de fecha
AllVar_df =sp500.join(macroeconomic_df, how='inner')

print(AllVar_df.index)
AllVar_df = AllVar_df.sort_index()
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2024-04-17', '2024-04-18', '2024-04-19', '2024-04-22',
#                '2024-04-23', '2024-04-24', '2024-04-25', '2024-04-26',
#                '2024-04-29', '2024-04-30'],
#               dtype='datetime64[ns]', name='Date', length=6120, freq=None)

# %%
# Unir el DataFrame 'oil' al 'AllVar_df' que ya contiene datos combinados de 'macroeconomic_df' y 'sp500'
# Asegúrate de que 'oil' está indexado adecuadamente, si es necesario
if 'Date' in oil.columns:
    oil.set_index('Date', inplace=True)

# Especificando sufijos para resolver el conflicto de nombres de columnas
AllVar_df = AllVar_df.join(oil, how='inner', lsuffix='_AllVar', rsuffix='_oil')

# Mostrar las primeras filas para verificar las nuevas columnas
print(AllVar_df.head())
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971  871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059  837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951  685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966  733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966  795600000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  T10Y2Y  T10Y3M  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...   -0.47   -0.56
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...   -0.46   -0.56
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...   -0.46   -0.58
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...   -0.45   -0.54
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...   -0.45   -0.50
#
#             T5YIE  DEXUSEU  DEXCHUS  DEXCAUS  DEXMXUS  VIXCLS  GVZCLS  \
# Date
# 2000-08-23    NaN   0.8967   8.2793   1.4877   9.2725   17.38     NaN
# 2000-08-24    NaN   0.9028   8.2799   1.4871   9.2440   17.04     NaN
# 2000-08-25    NaN   0.9024   8.2799   1.4828   9.2320   16.53     NaN
# 2000-08-28    NaN   0.9002   8.2799   1.4845   9.2130   16.54     NaN
# 2000-08-29    NaN   0.8966   8.2799   1.4868   9.2325   16.89     NaN
#
#             Close_oil
# Date
# 2000-08-23  32.049999
# 2000-08-24  31.629999
# 2000-08-25  32.049999
# 2000-08-28  32.869999
# 2000-08-29  32.720001
#
# [5 rows x 23 columns]

# %% [markdown]
# 4. Calculo metricas de cambios

# %% [markdown]
# 4.2 Calculo de las variables para análisis técnico (variables calculadas a partir de los precios de los activos). Ayudan a la toma de decisiones al dar información sobre el comportamiento de cada activo a través del tiempo.
# Buscan determinar tendencias en los precios.

# %% [markdown]
# Medias moviles (dias h'abiles)

# %%
#Calculo la media 
# Periodos para las medias móviles
moving_avg_periods = [5,10, 20,200]

# Calcular y asignar cada media móvil utilizando un bucle
for period in moving_avg_periods:
    AllVar_df[f'{period}d_moving_avg'] = AllVar_df['Close'].rolling(window=period).mean()

# Mostrar las primeras filas para verificar las nuevas columnas
AllVar_df.head()
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971  871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059  837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951  685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966  733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966  795600000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  DEXCHUS  DEXCAUS  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...   8.2793   1.4877
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...   8.2799   1.4871
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...   8.2799   1.4828
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...   8.2799   1.4845
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...   8.2799   1.4868
#
#             DEXMXUS  VIXCLS  GVZCLS  Close_oil  5d_moving_avg  10d_moving_avg  \
# Date
# 2000-08-23   9.2725   17.38     NaN  32.049999            NaN             NaN
# 2000-08-24   9.2440   17.04     NaN  31.629999            NaN             NaN
# 2000-08-25   9.2320   16.53     NaN  32.049999            NaN             NaN
# 2000-08-28   9.2130   16.54     NaN  32.869999            NaN             NaN
# 2000-08-29   9.2325   16.89     NaN  32.720001    1508.931982             NaN
#
#             20d_moving_avg  200d_moving_avg
# Date
# 2000-08-23             NaN              NaN
# 2000-08-24             NaN              NaN
# 2000-08-25             NaN              NaN
# 2000-08-28             NaN              NaN
# 2000-08-29             NaN              NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Media movil ultimos 10 días hábiles

# %%
#Calculo el promedio móvil ponderado de los ultimas 2 semanas

# Definimos los pesos decrecientes para los últimos 10 días hábiles.
weights = np.arange(1, 11)[::-1]  # Esto crea un array de numpy: [10, 9, ..., 2, 1]

# Calculamos el WMA para cada ventana de 10 días hábiles.
# Usamos apply para aplicar una función personalizada que calcula el WMA de manera vectorizada.
AllVar_df['10d_wma'] = AllVar_df['Close'].rolling(window=10).apply(lambda x: np.dot(x, weights) / weights.sum(), raw=True)

# Ahora, el DataFrame 'AllVar_df' contiene una nueva columna '10d_wma' con el WMA de 10 días.
# Muestra los primeros registros para verificar.
print(AllVar_df[['Close', '10d_wma']].head(20))
# Out:
#                   Close      10d_wma
# Date
# 2000-08-23  1505.969971          NaN
# 2000-08-24  1508.310059          NaN
# 2000-08-25  1506.449951          NaN
# 2000-08-28  1514.089966          NaN
# 2000-08-29  1509.839966          NaN
# 2000-08-30  1502.589966          NaN
# 2000-08-31  1517.680054          NaN
# 2000-09-01  1520.770020          NaN
# 2000-09-05  1507.079956          NaN
# 2000-09-06  1492.250000  1509.020898
# 2000-09-07  1502.510010  1509.418539
# 2000-09-08  1494.500000  1509.139617
# 2000-09-11  1489.260010  1508.886353
# 2000-09-12  1481.989990  1506.660358
# 2000-09-13  1484.910034  1504.753820
# 2000-09-14  1480.869995  1503.770554
# 2000-09-15  1465.810059  1499.100546
# 2000-09-18  1444.510010  1492.482180
# 2000-09-19  1459.900024  1487.495099
# 2000-09-20  1451.339966  1484.460556

# %% [markdown]
# Momentum

# %%
# Calcular el momentum como el cambio día a día en la columna 'Close'. Es lo mismo que el daily change pero en absoluto no porcentual
AllVar_df['Momentum'] = AllVar_df['Close'].diff()

print(AllVar_df.head())  # Mostrar las primeras filas para verificar la nueva columna
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971  871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059  837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951  685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966  733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966  795600000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  DEXMXUS  VIXCLS  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...   9.2725   17.38
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...   9.2440   17.04
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...   9.2320   16.53
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...   9.2130   16.54
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...   9.2325   16.89
#
#             GVZCLS  Close_oil  5d_moving_avg  10d_moving_avg  20d_moving_avg  \
# Date
# 2000-08-23     NaN  32.049999            NaN             NaN             NaN
# 2000-08-24     NaN  31.629999            NaN             NaN             NaN
# 2000-08-25     NaN  32.049999            NaN             NaN             NaN
# 2000-08-28     NaN  32.869999            NaN             NaN             NaN
# 2000-08-29     NaN  32.720001    1508.931982             NaN             NaN
#
#             200d_moving_avg  10d_wma  Momentum
# Date
# 2000-08-23              NaN      NaN       NaN
# 2000-08-24              NaN      NaN  2.340088
# 2000-08-25              NaN      NaN -1.860107
# 2000-08-28              NaN      NaN  7.640015
# 2000-08-29              NaN      NaN -4.250000
#
# [5 rows x 29 columns]

# %% [markdown]
# Stochastic %K
#
# El Stochastic %K es una medida de la posición relativa del precio de cierre actual en relación con el rango alto-bajo durante un número específico de períodos pasados. La fórmula para calcular el Stochastic %K es la siguiente:
#
# % K = [(C-LLn)/(HHn-LLn)]x 100�
#
# donde:
#
#
# C es el precio de cierre más reciente,
#
# LLn es el precio más bajo de los prcios bajos (Low) en los últimos n períodos,
# Hn  es el precio más alto de lso pecios altos (High) en los últimos n períodos,
# n es el número de períodos utilizados para el cálculo.
# El valor de n varía según el análisis, pero los valores comunes incluyen 14, 20 o cualquier otro valor dependiendo de la estrategia de trading

# %%
# Calcular el Stochastic %K para cada fila basado en los 20 días laborables previos
# Crear una función para encapsular el cálculo
#def calculate_stochastic_k(row_index, df):
    #if row_index < 19:  # Asegurar que haya suficientes datos para los primeros 19 registros
        #return None
    #else:
        #period = df['Close'][row_index-19:row_index+1]  # Seleccionar los últimos 20 registros hasta el índice actual
        #low_20 = period.min()
        #high_20 = period.max()
        #close_recent = df['Close'].iloc[row_index]
        #stochastic_k = ((close_recent - low_20) / (high_20 - low_20)) * 100
        #return stochastic_k

# Aplicar la función a cada fila
# Nota: Esto puede ser lento para DataFrames muy grandes debido al enfoque iterativo
#sp500['Stochastic_%K'] = [calculate_stochastic_k(i, sp500) for i in range(len(sp500))]

#print(sp500.tail())  # Mostrar las últimas filas para verificar la nueva columna
#sp500.head


# Crea una función para encapsular el cálculo del Stochastic %K
def calculate_stochastic_k(row_index, df):
    if row_index < 19:  # Asegurar que haya suficientes datos para los primeros 19 registros
        return None
    else:
        # Seleccionar los últimos 20 registros hasta el índice actual para las columnas 'High' y 'Low'
        high_period = df['High'][row_index-19:row_index+1]
        low_period = df['Low'][row_index-19:row_index+1]
        low_20 = low_period.min()
        high_20 = high_period.max()
        close_recent = df['Close'].iloc[row_index]
        
        # Calcular el Stochastic %K
        stochastic_k = ((close_recent - low_20) / (high_20 - low_20)) * 100
        return stochastic_k

# Aplica la función a cada fila
AllVar_df['Stochastic_%K'] = [calculate_stochastic_k(i, AllVar_df) for i in range(len(AllVar_df))]

# Muestra las últimas filas para verificar la nueva columna
print(AllVar_df.tail())
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2024-04-24  5084.859863  5089.479980  5047.020020  5071.629883  3656740000
# 2024-04-25  5019.879883  5057.750000  4990.580078  5048.419922  3958050000
# 2024-04-26  5084.649902  5114.620117  5073.140137  5099.959961  3604140000
# 2024-04-29  5114.129883  5123.490234  5088.649902  5116.169922  3447450000
# 2024-04-30  5103.779785  5110.830078  5035.310059  5035.689941  4082470000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  VIXCLS  GVZCLS  \
# Date                                                  ...
# 2024-04-24  5.41    0.76  6.13    1.48          3.19  ...   15.97   17.45
# 2024-04-25  5.45    0.75  6.17    1.47          3.24  ...   15.37   17.32
# 2024-04-26  5.39    0.72  6.12    1.45          3.16  ...   15.03   16.92
# 2024-04-29  5.35    0.72  6.08    1.45          3.12  ...   14.67   16.92
# 2024-04-30  5.41    0.72  6.13    1.44          3.18  ...   15.65   16.54
#
#             Close_oil  5d_moving_avg  10d_moving_avg  20d_moving_avg  \
# Date
# 2024-04-24  82.809998    5026.225977     5058.904004     5133.872046
# 2024-04-25  83.570000    5033.685938     5043.839990     5123.868530
# 2024-04-26  83.849998    5060.231934     5041.494971     5116.149023
# 2024-04-29  82.629997    5081.345898     5046.929980     5109.769019
# 2024-04-30  81.930000    5074.373926     5045.357959     5101.263013
#
#             200d_moving_avg      10d_wma   Momentum  Stochastic_%K
# Date
# 2024-04-24      4683.744802  5077.418759   1.080078      37.929201
# 2024-04-25      4686.790603  5049.196928 -23.209961      30.473144
# 2024-04-26      4689.929602  5034.303258  51.540039      47.166416
# 2024-04-29      4692.960251  5031.596014  16.209961      53.661347
# 2024-04-30      4695.611602  5030.495614 -80.479980      27.102908
#
# [5 rows x 30 columns]

# %% [markdown]
# Stochastic %D
#
# El indicador Stochastic %D es una media móvil del indicador Stochastic %K. Usualmente se calcula como la media móvil simple de los últimos 3 valores de %K. Para calcular el %D para las últimas 20 observaciones de tu DataFrame sp500, primero necesitaríamos calcular el %K como se discutió anteriormente, y luego aplicar una media móvil sobre esos valores de %K.

# %%
# Calcular el Stochastic %D como la media móvil simple de 3 días de %K
AllVar_df['Stochastic_%D'] = AllVar_df['Stochastic_%K'].rolling(window=3).mean()

# Si solo necesitas las últimas 20 observaciones para el %D, puedes hacer lo siguiente:
last_20_stochastic_D = AllVar_df['Stochastic_%D'][-20:]

print(last_20_stochastic_D)
AllVar_df.head(9)
# Out:
# Date
# 2024-04-03    76.922842
# 2024-04-04    57.726515
# 2024-04-05    55.575326
# 2024-04-08    53.829101
# 2024-04-09    64.992990
# 2024-04-10    54.961573
# 2024-04-11    53.283501
# 2024-04-12    35.318808
# 2024-04-15    25.095684
# 2024-04-16     7.141325
# 2024-04-17     5.118661
# 2024-04-18     4.821237
# 2024-04-19     4.569616
# 2024-04-22     8.741723
# 2024-04-23    20.099123
# 2024-04-24    31.278398
# 2024-04-25    35.328193
# 2024-04-26    38.522920
# 2024-04-29    43.766969
# 2024-04-30    42.643557
# Name: Stochastic_%D, dtype: float64
#                    Open         High          Low        Close      Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971   871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059   837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951   685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966   733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966   795600000
# 2000-08-30  1509.839966  1510.489990  1500.089966  1502.589966   818400000
# 2000-08-31  1502.589966  1525.209961  1502.589966  1517.680054  1056600000
# 2000-09-01  1517.680054  1530.089966  1515.530029  1520.770020   767700000
# 2000-09-05  1520.770020  1520.770020  1504.209961  1507.079956   838500000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  GVZCLS  Close_oil  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...     NaN  32.049999
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...     NaN  31.629999
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...     NaN  32.049999
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...     NaN  32.869999
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...     NaN  32.720001
# 2000-08-30  7.58    1.77  8.30    2.49          6.28  ...     NaN  33.400002
# 2000-08-31  7.52    1.79  8.24    2.51          6.43  ...     NaN  33.099998
# 2000-09-01  7.51    1.83  8.22    2.54          6.48  ...     NaN  33.380001
# 2000-09-05  7.51    1.82  8.22    2.53          6.41  ...     NaN  33.799999
#
#             5d_moving_avg  10d_moving_avg  20d_moving_avg  200d_moving_avg  \
# Date
# 2000-08-23            NaN             NaN             NaN              NaN
# 2000-08-24            NaN             NaN             NaN              NaN
# 2000-08-25            NaN             NaN             NaN              NaN
# 2000-08-28            NaN             NaN             NaN              NaN
# 2000-08-29    1508.931982             NaN             NaN              NaN
# 2000-08-30    1508.255981             NaN             NaN              NaN
# 2000-08-31    1510.129980             NaN             NaN              NaN
# 2000-09-01    1512.993994             NaN             NaN              NaN
# 2000-09-05    1511.591992             NaN             NaN              NaN
#
#             10d_wma   Momentum  Stochastic_%K  Stochastic_%D
# Date
# 2000-08-23      NaN        NaN            NaN            NaN
# 2000-08-24      NaN   2.340088            NaN            NaN
# 2000-08-25      NaN  -1.860107            NaN            NaN
# 2000-08-28      NaN   7.640015            NaN            NaN
# 2000-08-29      NaN  -4.250000            NaN            NaN
# 2000-08-30      NaN  -7.250000            NaN            NaN
# 2000-08-31      NaN  15.090088            NaN            NaN
# 2000-09-01      NaN   3.089966            NaN            NaN
# 2000-09-05      NaN -13.690063            NaN            NaN
#
# [9 rows x 31 columns]

# %% [markdown]
# El Índice de Fuerza Relativa
#
# El Índice de Fuerza Relativa (RSI, por sus siglas en inglés) es un indicador de momento que mide la magnitud de los movimientos recientes de precios para evaluar condiciones de sobrecompra o sobreventa en el precio de un activo. Se calcula utilizando la fórmula:
#
# RSI=100− 100/(1+RS)
#
#
# donde
# �
# �
# RS es la relación media de días de cierre hacia arriba entre la media de días de cierre hacia abajo. Para calcularlo para los últimos 20 y 10 días, necesitamos seguir los siguientes pasos para cada ventana de tiempo:
#
# Calcular los cambios diarios en el precio de cierre.
# Separar estos cambios en ganancias (aumentos) y pérdidas (disminuciones).
# Calcular el promedio de ganancias y el promedio de pérdidas sobre el período de interés (20 días y 10 días, respectivamente).
# Calcular el RS, que es el promedio de ganancias dividido por el promedio de pérdidas.
# Utilizar la fórmula del RSI para obtener el valor final.

# %%
# Separar las ganancias (positivas) de las pérdidas (negativas)
gain = AllVar_df['Momentum'].mask(AllVar_df['Momentum'] > 0, 0)
loss = -AllVar_df['Momentum'].mask(AllVar_df['Momentum'] < 0, 0)

# Calcular el RSI para los últimos 20 y 10 días
window_lengths = [20, 10]

for length in window_lengths:
    # Calcular el promedio de ganancias y pérdidas
    avg_gain = gain.rolling(window=length, min_periods=1).mean()
    avg_loss = loss.rolling(window=length, min_periods=1).mean()
    
    # Calcular RS
    rs = avg_gain / avg_loss
    
    # Calcular RSI
    rsi = 100 - (100 / (1 + rs))
    
    # Adjuntar al DataFrame
    AllVar_df[f'RSI_{length}'] = rsi

# Mostrar las últimas 20 filas para verificar las nuevas columnas
print(AllVar_df.tail(20))
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2024-04-03  5194.370117  5228.750000  5194.370117  5211.490234  3703250000
# 2024-04-04  5244.049805  5256.589844  5146.060059  5147.209961  4075680000
# 2024-04-05  5158.950195  5222.180176  5157.209961  5204.339844  3386780000
# 2024-04-08  5211.370117  5219.569824  5197.350098  5202.390137  3278180000
# 2024-04-09  5217.029785  5224.810059  5160.779785  5209.910156  3400680000
# 2024-04-10  5167.879883  5178.430176  5138.700195  5160.640137  3845930000
# 2024-04-11  5172.950195  5211.779785  5138.770020  5199.060059  3509380000
# 2024-04-12  5171.509766  5175.029785  5107.939941  5123.410156  3963220000
# 2024-04-15  5149.669922  5168.430176  5052.470215  5061.819824  3950210000
# 2024-04-16  5064.589844  5079.839844  5039.830078  5051.410156  4006200000
# 2024-04-17  5068.970215  5077.959961  5007.250000  5022.209961  3596130000
# 2024-04-18  5031.520020  5056.660156  5001.890137  5011.120117  3619760000
# 2024-04-19  5005.439941  5019.020020  4953.560059  4967.229980  3878750000
# 2024-04-22  4987.330078  5038.839844  4969.399902  5010.600098  3820250000
# 2024-04-23  5028.850098  5076.120117  5027.959961  5070.549805  3751400000
# 2024-04-24  5084.859863  5089.479980  5047.020020  5071.629883  3656740000
# 2024-04-25  5019.879883  5057.750000  4990.580078  5048.419922  3958050000
# 2024-04-26  5084.649902  5114.620117  5073.140137  5099.959961  3604140000
# 2024-04-29  5114.129883  5123.490234  5088.649902  5116.169922  3447450000
# 2024-04-30  5103.779785  5110.830078  5035.310059  5035.689941  4082470000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  5d_moving_avg  \
# Date                                                  ...
# 2024-04-03  5.12    0.76  5.85    1.49          3.23  ...    5232.782129
# 2024-04-04  5.08    0.77  5.82    1.51          3.24  ...    5212.526074
# 2024-04-05  5.16    0.77  5.88    1.49          3.18  ...    5202.524023
# 2024-04-08  5.16    0.74  5.88    1.46          3.15  ...    5194.248047
# 2024-04-09  5.10    0.74  5.80    1.44          3.14  ...    5195.068066
# 2024-04-10  5.24    0.69  5.95    1.40          3.10  ...    5184.898047
# 2024-04-11  5.27    0.71  5.97    1.41          3.16  ...    5195.268066
# 2024-04-12  5.22    0.72  5.95    1.45          3.25  ...    5179.082129
# 2024-04-15  5.37    0.74  6.09    1.46          3.28  ...    5150.968066
# 2024-04-16  5.40    0.73  6.13    1.46          3.36  ...    5119.268066
# 2024-04-17  5.34    0.75  6.07    1.48          3.42  ...    5091.582031
# 2024-04-18  5.40    0.76  6.11    1.47          3.39  ...    5053.994043
# 2024-04-19  5.35    0.73  6.08    1.46          3.37  ...    5022.758008
# 2024-04-22  5.35    0.73  6.08    1.46          3.29  ...    5012.514063
# 2024-04-23  5.34    0.73  6.07    1.46          3.20  ...    5016.341992
# 2024-04-24  5.41    0.76  6.13    1.48          3.19  ...    5026.225977
# 2024-04-25  5.45    0.75  6.17    1.47          3.24  ...    5033.685938
# 2024-04-26  5.39    0.72  6.12    1.45          3.16  ...    5060.231934
# 2024-04-29  5.35    0.72  6.08    1.45          3.12  ...    5081.345898
# 2024-04-30  5.41    0.72  6.13    1.44          3.18  ...    5074.373926
#
#             10d_moving_avg  20d_moving_avg  200d_moving_avg      10d_wma  \
# Date
# 2024-04-03     5228.601074     5186.291992      4630.915146  5230.118049
# 2024-04-04     5220.860059     5188.414502      4634.603247  5229.434402
# 2024-04-05     5217.141064     5190.763501      4638.681396  5225.000089
# 2024-04-08     5213.962061     5194.698511      4642.864897  5221.324068
# 2024-04-09     5213.134082     5199.297021      4647.004998  5220.404821
# 2024-04-10     5208.840088     5198.565527      4651.066548  5221.361186
# 2024-04-11     5203.897070     5200.253027      4655.417749  5213.253338
# 2024-04-12     5190.803076     5198.899536      4659.142749  5201.699334
# 2024-04-15     5172.608057     5196.136035      4662.567549  5188.760795
# 2024-04-16     5157.168066     5191.235547      4665.842400  5179.916797
# 2024-04-17     5138.240039     5183.420557      4668.701550  5166.598580
# 2024-04-18     5124.631055     5172.745557      4671.479202  5162.493324
# 2024-04-19     5100.920068     5159.030566      4674.081252  5143.689728
# 2024-04-22     5081.741064     5147.851562      4677.076304  5121.753533
# 2024-04-23     5067.805029     5140.469556      4680.434302  5095.916238
# 2024-04-24     5058.904004     5133.872046      4683.744802  5077.418759
# 2024-04-25     5043.839990     5123.868530      4686.790603  5049.196928
# 2024-04-26     5041.494971     5116.149023      4689.929602  5034.303258
# 2024-04-29     5046.929980     5109.769019      4692.960251  5031.596014
# 2024-04-30     5045.357959     5101.263013      4695.611602  5030.495614
#
#              Momentum  Stochastic_%K  Stochastic_%D     RSI_20     RSI_10
# Date
# 2024-04-03   5.680176      69.282209      76.922842  36.743012  41.993476
# 2024-04-04 -64.280273      32.277841      57.726515  46.063525  67.269040
# 2024-04-05  57.129883      65.165927      55.575326  45.679765  57.034221
# 2024-04-08  -1.949707      64.043535      53.829101  42.314434  56.138254
# 2024-04-09   7.520020      65.769507      64.992990  41.049476  51.652784
# 2024-04-10 -49.270020      35.071675      54.961573  51.446470  57.529621
# 2024-04-11  38.419922      59.009321      53.283501  46.840893  58.869584
# 2024-04-12 -75.649902      11.875426      35.318808  52.274814  68.789456
# 2024-04-15 -61.590332       4.402305      25.095684  54.434444  72.775079
# 2024-04-16 -10.409668       5.146243       7.141325  58.150236  70.758261
# 2024-04-17 -29.200195       5.807436       5.118661  62.995098  73.934084
# 2024-04-18 -11.089844       3.510033       4.821237  68.848456  69.882834
# 2024-04-19 -43.890137       4.391378       4.569616  73.114898  86.036057
# 2024-04-22  43.370117      18.323760       8.741723  67.762485  75.888874
# 2024-04-23  59.949707      37.582232      20.099123  60.963596  66.479094
# 2024-04-24   1.080078      37.929201      31.278398  59.999408  61.879124
# 2024-04-25 -23.209961      30.473144      35.328193  65.677284  70.954841
# 2024-04-26  51.540039      47.166416      38.522920  61.289625  53.496584
# 2024-04-29  16.209961      53.661347      43.766969  59.254433  40.627668
# 2024-04-30 -80.479980      27.102908      42.643557  61.621498  52.183242
#
# [20 rows x 33 columns]

# %% [markdown]
# Indicador Larry Williams %R
#
# El indicador Larry Williams %R es una medida de momentum que se utiliza para identificar niveles de sobrecompra y sobreventa en un mercado. Se calcula como un porcentaje que refleja la posición del precio de cierre relativo a su rango más alto y más bajo durante un número específico de períodos pasados. La fórmula del Larry Williams %R es:
#
# %R= [(Hn-C)/(Hn-Ln)]x100
#
# donde:
#
# C es el precio de cierre actual,
# Hn  es el precio más alto en los últimos n períodos,
# Ln es el precio más bajo en los últimos
# �
# n períodos,
# �
# n es el número de períodos utilizados para el cálculo.
# Generalmente, se utiliza un período de 14 días para el cálculo de este indicador, pero se puede ajustar según las necesidades del análisis. Para agregar el Larry Williams %R al DataFrame sp500 para los últimos 14 días, puedes usar el siguiente código:

# %%
# Asumiendo que sp500 es tu DataFrame y tiene columnas 'High', 'Low', y 'Close' con los precios más altos, más bajos y de cierre

# Configurar el número de períodos para el cálculo de Williams %R
n = 10

# Calcular el precio más alto y el más bajo de los últimos n días
high_n = AllVar_df['High'].rolling(window=n).max()
low_n = AllVar_df['Low'].rolling(window=n).min()

# Calcular el Williams %R
AllVar_df['Williams_%R'] = ((high_n - AllVar_df['Close']) / (high_n - low_n)) * -100

# Mostrar las últimas filas para verificar la nueva columna
print(AllVar_df.tail())
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2024-04-24  5084.859863  5089.479980  5047.020020  5071.629883  3656740000
# 2024-04-25  5019.879883  5057.750000  4990.580078  5048.419922  3958050000
# 2024-04-26  5084.649902  5114.620117  5073.140137  5099.959961  3604140000
# 2024-04-29  5114.129883  5123.490234  5088.649902  5116.169922  3447450000
# 2024-04-30  5103.779785  5110.830078  5035.310059  5035.689941  4082470000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  10d_moving_avg  \
# Date                                                  ...
# 2024-04-24  5.41    0.76  6.13    1.48          3.19  ...     5058.904004
# 2024-04-25  5.45    0.75  6.17    1.47          3.24  ...     5043.839990
# 2024-04-26  5.39    0.72  6.12    1.45          3.16  ...     5041.494971
# 2024-04-29  5.35    0.72  6.08    1.45          3.12  ...     5046.929980
# 2024-04-30  5.41    0.72  6.13    1.44          3.18  ...     5045.357959
#
#             20d_moving_avg  200d_moving_avg      10d_wma   Momentum  \
# Date
# 2024-04-24     5133.872046      4683.744802  5077.418759   1.080078
# 2024-04-25     5123.868530      4686.790603  5049.196928 -23.209961
# 2024-04-26     5116.149023      4689.929602  5034.303258  51.540039
# 2024-04-29     5109.769019      4692.960251  5031.596014  16.209961
# 2024-04-30     5101.263013      4695.611602  5030.495614 -80.479980
#
#             Stochastic_%K  Stochastic_%D     RSI_20     RSI_10  Williams_%R
# Date
# 2024-04-24      37.929201      31.278398  59.999408  61.879124   -54.275444
# 2024-04-25      30.473144      35.328193  65.677284  70.954841   -57.168023
# 2024-04-26      47.166416      38.522920  61.289625  53.496584   -31.865862
# 2024-04-29      53.661347      43.766969  59.254433  40.627668    -4.307836
# 2024-04-30      27.102908      42.643557  61.621498  52.183242   -51.668453
#
# [5 rows x 34 columns]

# %% [markdown]
# Moving Average Convergence/Divergence Oscillator
#
# The MACD turns two trend-following indicators, moving averages, into a momentum oscillator by subtracting the longer moving average from the shorter one. As a result, the MACD offers the best of both worlds: trend following and momentum. The MACD fluctuates above and below the zero line as the moving averages converge, cross and diverge. Traders can look for signal line crossovers, centerline crossovers and divergences to generate signals. Because the MACD is unbounded, it is not particularly useful for identifying overbought and oversold levels.

# %%
#https://school.stockcharts.com/doku.php?id=technical_indicators:moving_average_convergence_divergence_macd


# Calcular las EMAs de 12 y 26 períodos para la columna 'Close'
ema12 = AllVar_df['Close'].ewm(span=12, adjust=False).mean()
ema26 = AllVar_df['Close'].ewm(span=26, adjust=False).mean()

# Calcular el MACD restando la EMA de 26 períodos de la EMA de 12 períodos
AllVar_df['MACD'] = ema12 - ema26

# Calcular la línea de señal como la EMA de 9 períodos del MACD
AllVar_df['Signal_Line'] = AllVar_df['MACD'].ewm(span=9, adjust=False).mean()

# Mostrar las últimas filas para verificar las nuevas columnas
print(AllVar_df.tail())
AllVar_df.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2024-04-24  5084.859863  5089.479980  5047.020020  5071.629883  3656740000
# 2024-04-25  5019.879883  5057.750000  4990.580078  5048.419922  3958050000
# 2024-04-26  5084.649902  5114.620117  5073.140137  5099.959961  3604140000
# 2024-04-29  5114.129883  5123.490234  5088.649902  5116.169922  3447450000
# 2024-04-30  5103.779785  5110.830078  5035.310059  5035.689941  4082470000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  200d_moving_avg  \
# Date                                                  ...
# 2024-04-24  5.41    0.76  6.13    1.48          3.19  ...      4683.744802
# 2024-04-25  5.45    0.75  6.17    1.47          3.24  ...      4686.790603
# 2024-04-26  5.39    0.72  6.12    1.45          3.16  ...      4689.929602
# 2024-04-29  5.35    0.72  6.08    1.45          3.12  ...      4692.960251
# 2024-04-30  5.41    0.72  6.13    1.44          3.18  ...      4695.611602
#
#                 10d_wma   Momentum  Stochastic_%K  Stochastic_%D     RSI_20  \
# Date
# 2024-04-24  5077.418759   1.080078      37.929201      31.278398  59.999408
# 2024-04-25  5049.196928 -23.209961      30.473144      35.328193  65.677284
# 2024-04-26  5034.303258  51.540039      47.166416      38.522920  61.289625
# 2024-04-29  5031.596014  16.209961      53.661347      43.766969  59.254433
# 2024-04-30  5030.495614 -80.479980      27.102908      42.643557  61.621498
#
#                RSI_10  Williams_%R       MACD  Signal_Line
# Date
# 2024-04-24  61.879124   -54.275444 -30.896300   -16.011605
# 2024-04-25  70.954841   -57.168023 -30.741278   -18.957539
# 2024-04-26  53.496584   -31.865862 -26.158038   -20.397639
# 2024-04-29  40.627668    -4.307836 -20.975981   -20.513307
# 2024-04-30  52.183242   -51.668453 -23.096977   -21.030041
#
# [5 rows x 36 columns]
#                    Open         High          Low        Close     Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971  871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059  837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951  685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966  733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966  795600000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  200d_moving_avg  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...              NaN
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...              NaN
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...              NaN
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...              NaN
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...              NaN
#
#             10d_wma  Momentum  Stochastic_%K  Stochastic_%D     RSI_20  \
# Date
# 2000-08-23      NaN       NaN            NaN            NaN        NaN
# 2000-08-24      NaN  2.340088            NaN            NaN   0.000000
# 2000-08-25      NaN -1.860107            NaN            NaN  44.286213
# 2000-08-28      NaN  7.640015            NaN            NaN  15.710088
# 2000-08-29      NaN -4.250000            NaN            NaN  37.974069
#
#                RSI_10  Williams_%R      MACD  Signal_Line
# Date
# 2000-08-23        NaN          NaN  0.000000     0.000000
# 2000-08-24   0.000000          NaN  0.186674     0.037335
# 2000-08-25  44.286213          NaN  0.182416     0.066351
# 2000-08-28  15.710088          NaN  0.786461     0.210373
# 2000-08-29  37.974069          NaN  0.911722     0.350643
#
# [5 rows x 36 columns]

# %% [markdown]
# 4.3 Cambios diarios
# Trabajo con daily changes y no números absolutos porque ARIMA y modelos en general trabajan mejor con series estacionarias. Para observaciones diarias, los cambios diarios son una forma común de estacionarizar la serie temporal.

# %%
# Calcular los retornos diarios 
retornos_diarios = AllVar_df[['Close']].pct_change()

# Multiplicar por 100 para obtener porcentajes
retornos_diarios = retornos_diarios * 100

# Añadir la columna de retornos diarios al DataFrame original
# Nombrando la columna como 'Retornos Diarios'
AllVar_df['Daily Returns'] = retornos_diarios

# %%
columns_to_change = [
    'DAAA', 'AAA10Y', 'DBAA', 'BAA10Y', 'BAMLH0A0HYM2', 'BAMLH0A2HYB', 
    'BAMLH0A3HYC', 'BAMLHE00EHYIOAS', 'T10Y2Y', 'T10Y3M', 'T5YIE', 'DEXUSEU', 
    'DEXCHUS', 'DEXCAUS', 'DEXMXUS', 'VIXCLS', 'GVZCLS'
]
for column in columns_to_change:
    new_column_name = f'{column}_daily_change'
    AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100

print(AllVar_df.head())
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971  871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059  837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951  685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966  733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966  795600000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...
#
#             BAMLHE00EHYIOAS_daily_change  T10Y2Y_daily_change  \
# Date
# 2000-08-23                           NaN                  NaN
# 2000-08-24                      3.937008            -2.127660
# 2000-08-25                     -0.252525             0.000000
# 2000-08-28                      0.000000            -2.173913
# 2000-08-29                     -1.898734             0.000000
#
#             T10Y3M_daily_change  T5YIE_daily_change  DEXUSEU_daily_change  \
# Date
# 2000-08-23                  NaN                 NaN                   NaN
# 2000-08-24             0.000000                 NaN              0.680272
# 2000-08-25             3.571429                 NaN             -0.044307
# 2000-08-28            -6.896552                 NaN             -0.243794
# 2000-08-29            -7.407407                 NaN             -0.399911
#
#             DEXCHUS_daily_change  DEXCAUS_daily_change  DEXMXUS_daily_change  \
# Date
# 2000-08-23                   NaN                   NaN                   NaN
# 2000-08-24              0.007247             -0.040331             -0.307360
# 2000-08-25              0.000000             -0.289153             -0.129814
# 2000-08-28              0.000000              0.114648             -0.205806
# 2000-08-29              0.000000              0.154934              0.211657
#
#             VIXCLS_daily_change  GVZCLS_daily_change
# Date
# 2000-08-23                  NaN                  NaN
# 2000-08-24            -1.956272                  NaN
# 2000-08-25            -2.992958                  NaN
# 2000-08-28             0.060496                  NaN
# 2000-08-29             2.116082                  NaN
#
# [5 rows x 54 columns]
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100
# C:\Users\lgarn\AppData\Local\Temp\ipykernel_17616\2385237343.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   AllVar_df[new_column_name] = AllVar_df[column].pct_change() * 100

# %%
# Calcula los cambios diarios en el precio del oil.
AllVar_df['oil_daily_changes'] = AllVar_df['Close_oil'].pct_change() * 100  # Multiplicar por 100 para convertir a porcentaje

# %%
AllVar_df.head()
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2000-08-23  1498.130005  1507.199951  1489.520020  1505.969971  871000000
# 2000-08-24  1505.969971  1511.160034  1501.250000  1508.310059  837100000
# 2000-08-25  1508.310059  1513.469971  1505.089966  1506.449951  685600000
# 2000-08-28  1506.449951  1523.949951  1506.449951  1514.089966  733600000
# 2000-08-29  1514.089966  1514.810059  1505.459961  1509.839966  795600000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  \
# Date                                                  ...
# 2000-08-23  7.55    1.82  8.26    2.53          6.43  ...
# 2000-08-24  7.51    1.78  8.22    2.49          6.44  ...
# 2000-08-25  7.52    1.79  8.23    2.50          6.42  ...
# 2000-08-28  7.56    1.78  8.27    2.49          6.36  ...
# 2000-08-29  7.58    1.77  8.30    2.49          6.30  ...
#
#             T10Y2Y_daily_change  T10Y3M_daily_change  T5YIE_daily_change  \
# Date
# 2000-08-23                  NaN                  NaN                 NaN
# 2000-08-24            -2.127660             0.000000                 NaN
# 2000-08-25             0.000000             3.571429                 NaN
# 2000-08-28            -2.173913            -6.896552                 NaN
# 2000-08-29             0.000000            -7.407407                 NaN
#
#             DEXUSEU_daily_change  DEXCHUS_daily_change  DEXCAUS_daily_change  \
# Date
# 2000-08-23                   NaN                   NaN                   NaN
# 2000-08-24              0.680272              0.007247             -0.040331
# 2000-08-25             -0.044307              0.000000             -0.289153
# 2000-08-28             -0.243794              0.000000              0.114648
# 2000-08-29             -0.399911              0.000000              0.154934
#
#             DEXMXUS_daily_change  VIXCLS_daily_change  GVZCLS_daily_change  \
# Date
# 2000-08-23                   NaN                  NaN                  NaN
# 2000-08-24             -0.307360            -1.956272                  NaN
# 2000-08-25             -0.129814            -2.992958                  NaN
# 2000-08-28             -0.205806             0.060496                  NaN
# 2000-08-29              0.211657             2.116082                  NaN
#
#             oil_daily_changes
# Date
# 2000-08-23                NaN
# 2000-08-24          -1.310453
# 2000-08-25           1.327854
# 2000-08-28           2.558501
# 2000-08-29          -0.456336
#
# [5 rows x 55 columns]

# %%
# Contar los valores nulos en cada columna
null_counts_All = AllVar_df.isnull().sum()
print("Conteo de valores nulos por columna antes de limpiar:\n", null_counts_All)

# Reemplazar los valores infinitos por NaN
AllVar_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Eliminar las filas con valores nulos o NaN
AllVar_df = AllVar_df.dropna()

# Contar de nuevo los valores nulos en cada columna
null_counts_clean = AllVar_df.isnull().sum()
print("Conteo de valores nulos por columna después de limpiar:\n", null_counts_clean)

# Guardar el DataFrame limpio a un archivo CSV
#AllVar_df.to_csv("AllVar_df_clean.csv", index=False)
# Out:
# Conteo de valores nulos por columna antes de limpiar:
#  Open                               0
# High                               0
# Low                                0
# Close                              0
# Volume                             0
# DAAA                              39
# AAA10Y                            44
# DBAA                              39
# BAA10Y                            44
# BAMLH0A0HYM2                       2
# BAMLH0A2HYB                        2
# BAMLH0A3HYC                        2
# BAMLHE00EHYIOAS                    2
# T10Y2Y                            42
# T10Y3M                            42
# T5YIE                            622
# DEXUSEU                           53
# DEXCHUS                           53
# DEXCAUS                           53
# DEXMXUS                           53
# VIXCLS                             0
# GVZCLS                          1940
# Close_oil                          0
# 5d_moving_avg                      4
# 10d_moving_avg                     9
# 20d_moving_avg                    19
# 200d_moving_avg                  199
# 10d_wma                            9
# Momentum                           1
# Stochastic_%K                     19
# Stochastic_%D                     21
# RSI_20                             1
# RSI_10                             1
# Williams_%R                        9
# MACD                               0
# Signal_Line                        0
# Daily Returns                      1
# DAAA_daily_change                  1
# AAA10Y_daily_change                1
# DBAA_daily_change                  1
# BAA10Y_daily_change                1
# BAMLH0A0HYM2_daily_change          1
# BAMLH0A2HYB_daily_change           1
# BAMLH0A3HYC_daily_change           1
# BAMLHE00EHYIOAS_daily_change       1
# T10Y2Y_daily_change                3
# T10Y3M_daily_change                2
# T5YIE_daily_change               586
# DEXUSEU_daily_change               1
# DEXCHUS_daily_change               1
# DEXCAUS_daily_change               1
# DEXMXUS_daily_change               1
# VIXCLS_daily_change                1
# GVZCLS_daily_change             1941
# oil_daily_changes                  1
# dtype: int64
# Conteo de valores nulos por columna después de limpiar:
#  Open                            0
# High                            0
# Low                             0
# Close                           0
# Volume                          0
# DAAA                            0
# AAA10Y                          0
# DBAA                            0
# BAA10Y                          0
# BAMLH0A0HYM2                    0
# BAMLH0A2HYB                     0
# BAMLH0A3HYC                     0
# BAMLHE00EHYIOAS                 0
# T10Y2Y                          0
# T10Y3M                          0
# T5YIE                           0
# DEXUSEU                         0
# DEXCHUS                         0
# DEXCAUS                         0
# DEXMXUS                         0
# VIXCLS                          0
# GVZCLS                          0
# Close_oil                       0
# 5d_moving_avg                   0
# 10d_moving_avg                  0
# 20d_moving_avg                  0
# 200d_moving_avg                 0
# 10d_wma                         0
# Momentum                        0
# Stochastic_%K                   0
# Stochastic_%D                   0
# RSI_20                          0
# RSI_10                          0
# Williams_%R                     0
# MACD                            0
# Signal_Line                     0
# Daily Returns                   0
# DAAA_daily_change               0
# AAA10Y_daily_change             0
# DBAA_daily_change               0
# BAA10Y_daily_change             0
# BAMLH0A0HYM2_daily_change       0
# BAMLH0A2HYB_daily_change        0
# BAMLH0A3HYC_daily_change        0
# BAMLHE00EHYIOAS_daily_change    0
# T10Y2Y_daily_change             0
# T10Y3M_daily_change             0
# T5YIE_daily_change              0
# DEXUSEU_daily_change            0
# DEXCHUS_daily_change            0
# DEXCAUS_daily_change            0
# DEXMXUS_daily_change            0
# VIXCLS_daily_change             0
# GVZCLS_daily_change             0
# oil_daily_changes               0
# dtype: int64

# %% [markdown]
# IMPORTANTE: cuando se unen todas las variables en AllVar_df, se cambia año de inicio al 2008 porque es cuando hay datos para todas.

# %%
AllVar_df.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2008-06-04  1376.260010  1388.180054  1371.739990  1377.199951  4338640000
# 2008-06-05  1377.479980  1404.050049  1377.479980  1404.050049  4350790000
# 2008-06-06  1400.060059  1400.060059  1359.900024  1360.680054  4771660000
# 2008-06-09  1360.829956  1370.630005  1350.619995  1361.760010  4404570000
# 2008-06-10  1358.979980  1366.839966  1351.560059  1358.439941  4635070000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  \
# Date                                                  ...
# 2008-06-04  5.64    1.66  7.02    3.04          6.79  ...
# 2008-06-05  5.69    1.63  7.07    3.01          6.63  ...
# 2008-06-06  5.61    1.67  6.98    3.04          6.68  ...
# 2008-06-09  5.58    1.56  6.96    2.94          6.58  ...
# 2008-06-10  5.66    1.55  7.05    2.94          6.49  ...
#
#             T10Y2Y_daily_change  T10Y3M_daily_change  T5YIE_daily_change  \
# Date
# 2008-06-04             2.721088             3.381643           -1.694915
# 2008-06-05             1.986755             3.271028            2.155172
# 2008-06-06             0.000000            -5.429864            3.375527
# 2008-06-09           -16.233766             1.913876            1.224490
# 2008-06-10            -6.976744            -1.877934            0.000000
#
#             DEXUSEU_daily_change  DEXCHUS_daily_change  DEXCAUS_daily_change  \
# Date
# 2008-06-04             -0.006471              0.421107              0.935230
# 2008-06-05              0.692422             -0.248445              0.492854
# 2008-06-06              1.098972             -0.331126             -0.078470
# 2008-06-09             -0.082639              0.000000              0.353392
# 2008-06-10             -1.558722              0.026000              0.176074
#
#             DEXMXUS_daily_change  VIXCLS_daily_change  GVZCLS_daily_change  \
# Date
# 2008-06-04              0.291545             2.766798            -0.873744
# 2008-06-05             -0.077519           -10.432692             0.396651
# 2008-06-06              0.543057            26.462695             3.599649
# 2008-06-09             -0.038580            -1.867572             3.686441
# 2008-06-10              0.231571             0.259516             3.759706
#
#             oil_daily_changes
# Date
# 2008-06-04          -1.616921
# 2008-06-05           4.488960
# 2008-06-06           8.412233
# 2008-06-09          -3.024388
# 2008-06-10          -2.262753
#
# [5 rows x 55 columns]

# %%
# Crear un "lag" de 1 día para los retornos diarios
AllVar_df['Lag 1_Returns'] = AllVar_df['Daily Returns'].shift(+1)
AllVar_df['Lag 2_Returns'] = AllVar_df['Daily Returns'].shift(+2)
AllVar_df['Next_Day_Returns'] = AllVar_df['Daily Returns'].shift(-1)

# Crear la columna 'TARGET' basada en 'Lagged_Daily_Returns' - Quiero predecir si el retorno del día siguiente será positivo o negativo basado con respecto al día actual en el que tomo la decision al final del día
AllVar_df['TARGET'] = np.where(AllVar_df['Next_Day_Returns'] > 0, 1, 0)

# Mostrar las primeras filas para verificar las nuevas columnas
AllVar_df.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2008-06-04  1376.260010  1388.180054  1371.739990  1377.199951  4338640000
# 2008-06-05  1377.479980  1404.050049  1377.479980  1404.050049  4350790000
# 2008-06-06  1400.060059  1400.060059  1359.900024  1360.680054  4771660000
# 2008-06-09  1360.829956  1370.630005  1350.619995  1361.760010  4404570000
# 2008-06-10  1358.979980  1366.839966  1351.560059  1358.439941  4635070000
#
#             DAAA  AAA10Y  DBAA  BAA10Y  BAMLH0A0HYM2  ...  \
# Date                                                  ...
# 2008-06-04  5.64    1.66  7.02    3.04          6.79  ...
# 2008-06-05  5.69    1.63  7.07    3.01          6.63  ...
# 2008-06-06  5.61    1.67  6.98    3.04          6.68  ...
# 2008-06-09  5.58    1.56  6.96    2.94          6.58  ...
# 2008-06-10  5.66    1.55  7.05    2.94          6.49  ...
#
#             DEXCHUS_daily_change  DEXCAUS_daily_change  DEXMXUS_daily_change  \
# Date
# 2008-06-04              0.421107              0.935230              0.291545
# 2008-06-05             -0.248445              0.492854             -0.077519
# 2008-06-06             -0.331126             -0.078470              0.543057
# 2008-06-09              0.000000              0.353392             -0.038580
# 2008-06-10              0.026000              0.176074              0.231571
#
#             VIXCLS_daily_change  GVZCLS_daily_change  oil_daily_changes  \
# Date
# 2008-06-04             2.766798            -0.873744          -1.616921
# 2008-06-05           -10.432692             0.396651           4.488960
# 2008-06-06            26.462695             3.599649           8.412233
# 2008-06-09            -1.867572             3.686441          -3.024388
# 2008-06-10             0.259516             3.759706          -2.262753
#
#             Lag 1_Returns  Lag 2_Returns  Next_Day_Returns  TARGET
# Date
# 2008-06-04            NaN            NaN          1.949615       1
# 2008-06-05      -0.032670            NaN         -3.088921       0
# 2008-06-06       1.949615      -0.032670          0.079369       1
# 2008-06-09      -3.088921       1.949615         -0.243807       0
# 2008-06-10       0.079369      -3.088921         -1.689434       0
#
# [5 rows x 59 columns]

# %% [markdown]
# Variables control

# %% [markdown]
# Para los tres modelos probé iniciar el 30-Abril de  2014, 2019, 2022.  EL logit mejora  conforme utiliza menos periodo de tiempo. Random forest da mejor a partir del 2014 y emperoa si utilizamos 2019 y 2022 como puntos de inicio.  Para  guardar en csv los resutlados de cada estraegia de cada modelo con la fecha respectiva.

# %% [markdown]
# Selecciono el tamaño del periodo de prueba y la fecha de inicio de análisis para el que el periodo de prueba se mantenga como una serie de tiempo en orden histórico.

# %%
fecha_inicio = '2014-04-30'
test_size_Control=0.2

# %%
# Convertir a datetime
fecha_inicio_1 = pd.to_datetime(fecha_inicio)
end_date_1 = pd.to_datetime(end_date)


# Calcular el total de días
total_dias = (end_date_1 - fecha_inicio_1).days

# Calcular el número de días para el entrenamiento
dias_entrenamiento = int(total_dias * (1 - test_size_Control))

# Calcular la fecha de corte
fecha_corte = fecha_inicio_1 + pd.Timedelta(days=dias_entrenamiento)

print("Fecha de corte para dividir los datos:", fecha_corte)
print("incio:", fecha_inicio)
# Out:
# Fecha de corte para dividir los datos: 2022-04-30 00:00:00
# incio: 2014-04-30

# %%
AllVar_df_Shortened = AllVar_df.loc[fecha_inicio:]

# %% [markdown]
# LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from tensorflow.keras.utils import to_categorical

# %%
print(AllVar_df.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'DAAA', 'AAA10Y', 'DBAA',
#        'BAA10Y', 'BAMLH0A0HYM2', 'BAMLH0A2HYB', 'BAMLH0A3HYC',
#        'BAMLHE00EHYIOAS', 'T10Y2Y', 'T10Y3M', 'T5YIE', 'DEXUSEU', 'DEXCHUS',
#        'DEXCAUS', 'DEXMXUS', 'VIXCLS', 'GVZCLS', 'Close_oil', '5d_moving_avg',
#        '10d_moving_avg', '20d_moving_avg', '200d_moving_avg', '10d_wma',
#        'Momentum', 'Stochastic_%K', 'Stochastic_%D', 'RSI_20', 'RSI_10',
#        'Williams_%R', 'MACD', 'Signal_Line', 'Daily Returns',
#        'DAAA_daily_change', 'AAA10Y_daily_change', 'DBAA_daily_change',
#        'BAA10Y_daily_change', 'BAMLH0A0HYM2_daily_change',
#        'BAMLH0A2HYB_daily_change', 'BAMLH0A3HYC_daily_change',
#        'BAMLHE00EHYIOAS_daily_change', 'T10Y2Y_daily_change',
#        'T10Y3M_daily_change', 'T5YIE_daily_change', 'DEXUSEU_daily_change',
#        'DEXCHUS_daily_change', 'DEXCAUS_daily_change', 'DEXMXUS_daily_change',
#        'VIXCLS_daily_change', 'GVZCLS_daily_change', 'oil_daily_changes',
#        'Lag 1_Returns', 'Lag 2_Returns', 'Next_Day_Returns', 'TARGET'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

AllVar_df_Shortened.index = pd.to_datetime(AllVar_df_Shortened.index)

# Asumiendo que TARGET está alineado con AllVar_df_Shortened
AllVar_df_Shortened['TARGET'].index = AllVar_df_Shortened.index


X_LSTM = AllVar_df_Shortened[['Volume', 
        'VIXCLS', 'GVZCLS',  '20d_moving_avg','200d_moving_avg', '10d_wma',
       'Momentum', 'Stochastic_%K', 'Stochastic_%D', 'RSI_20', 'RSI_10',
       'Williams_%R', 'MACD', 'Signal_Line', 'Daily Returns',
       'DAAA_daily_change', 'AAA10Y_daily_change', 'DBAA_daily_change',
       'BAA10Y_daily_change', 'BAMLH0A0HYM2_daily_change',
       'BAMLH0A2HYB_daily_change', 'BAMLH0A3HYC_daily_change',
       'BAMLHE00EHYIOAS_daily_change', 'T10Y2Y_daily_change',
       'T10Y3M_daily_change', 'T5YIE_daily_change', 'DEXUSEU_daily_change',
       'DEXCHUS_daily_change', 'DEXCAUS_daily_change', 'DEXMXUS_daily_change',
       'VIXCLS_daily_change', 'GVZCLS_daily_change', 'oil_daily_changes',
       'Lag 1_Returns', 'Lag 2_Returns']]
Y_LSTM = AllVar_df_Shortened['TARGET']


# Dividir los datos usando la fecha de corte
train_mask_LSTM = X_LSTM.index <= fecha_corte
test_mask_LSTM = X_LSTM.index > fecha_corte

X_train_LSTM = X_LSTM[train_mask_LSTM]
Y_train_LSTM = Y_LSTM[train_mask_LSTM]
X_test_LSTM = X_LSTM[test_mask_LSTM]
Y_test_LSTM = Y_LSTM[test_mask_LSTM]


# Inicializar el escalador
scaler = StandardScaler()

# Ajustar el escalador a los datos de entrenamiento y transformarlos
X_train_scaled_LSTM = scaler.fit_transform(X_train_LSTM)
X_test_scaled_LSTM = scaler.transform(X_test_LSTM)

# %%
X_train_LSTM.head()
# Out:
#                 Volume  VIXCLS  GVZCLS  20d_moving_avg  200d_moving_avg  \
# Date
# 2014-04-30  3779230000   13.41   15.52     1863.200500      1775.041602
# 2014-05-01  3416740000   13.25   15.15     1862.839502      1776.078702
# 2014-05-02  3159560000   12.91   14.85     1862.458002      1777.079852
# 2014-05-05  2733730000   13.29   15.51     1863.436505      1778.056302
# 2014-05-06  3327260000   13.80   15.02     1864.570502      1778.934452
#
#                 10d_wma   Momentum  Stochastic_%K  Stochastic_%D     RSI_20  \
# Date
# 2014-04-30  1870.665654   5.619995      83.924179      75.828069  50.324568
# 2014-05-01  1872.956190  -0.269897      83.598687      81.556479  51.524745
# 2014-05-02  1875.081106  -2.540039      80.535449      82.686105  51.608552
# 2014-05-05  1876.158196   3.520020      91.334384      85.156173  45.490976
# 2014-05-06  1875.627461 -16.940063      69.325719      80.398517  44.698477
#
#             ...  T5YIE_daily_change  DEXUSEU_daily_change  \
# Date        ...
# 2014-04-30  ...            0.512821              0.449015
# 2014-05-01  ...            0.000000             -0.021629
# 2014-05-02  ...           -0.510204             -0.021634
# 2014-05-05  ...           -1.538462              0.144259
# 2014-05-06  ...           -0.520833              0.288101
#
#             DEXCHUS_daily_change  DEXCAUS_daily_change  DEXMXUS_daily_change  \
# Date
# 2014-04-30              0.020774             -0.063851             -0.243986
# 2014-05-01              0.000000              0.082147             -0.236940
# 2014-05-02              0.000000              0.072959             -0.413714
# 2014-05-05             -0.220479             -0.164039              0.073085
# 2014-05-06             -0.317038             -0.593336             -0.042282
#
#             VIXCLS_daily_change  GVZCLS_daily_change  oil_daily_changes  \
# Date
# 2014-04-30            -2.188184             1.371653          -1.520538
# 2014-05-01            -1.193139            -2.384021          -0.320834
# 2014-05-02            -2.566038            -1.980198           0.341988
# 2014-05-05             2.943455             4.444444          -0.280672
# 2014-05-06             3.837472            -3.159252           0.020101
#
#             Lag 1_Returns  Lag 2_Returns
# Date
# 2014-04-30       0.476076       0.323604
# 2014-05-01       0.299202       0.476076
# 2014-05-02      -0.014326       0.299202
# 2014-05-05      -0.134845      -0.014326
# 2014-05-06       0.187122      -0.134845
#
# [5 rows x 35 columns]

# %%
X_test_LSTM.head()
# Out:
#                 Volume  VIXCLS  GVZCLS  20d_moving_avg  200d_moving_avg  \
# Date
# 2022-05-02  5163790000   32.34   20.06     4371.771997      4491.886443
# 2022-05-03  4582050000   29.25   19.71     4351.413989      4491.471392
# 2022-05-04  5136360000   25.42   18.81     4340.166479      4491.356941
# 2022-05-05  5077030000   31.20   19.36     4323.452490      4490.297842
# 2022-05-06  5116940000   30.19   18.71     4304.608984      4489.077141
#
#                 10d_wma    Momentum  Stochastic_%K  Stochastic_%D     RSI_20  \
# Date
# 2022-05-02  4335.985325   23.449707      17.491589      15.809827  68.390073
# 2022-05-03  4297.955522   20.100098      21.277344      13.466518  69.481730
# 2022-05-04  4257.531490  124.689941      51.817254      30.195396  60.113308
# 2022-05-05  4224.582191 -153.299805      18.393128      30.495909  63.683403
# 2022-05-06  4211.094052  -23.530273      13.284519      27.831634  65.370544
#
#             ...  T5YIE_daily_change  DEXUSEU_daily_change  \
# Date        ...
# 2022-05-02  ...           -2.727273             -0.151846
# 2022-05-03  ...            0.000000              0.104553
# 2022-05-04  ...            0.934579              0.066464
# 2022-05-05  ...           -0.308642             -0.303634
# 2022-05-06  ...           -0.309598              0.618635
#
#             DEXCHUS_daily_change  DEXCAUS_daily_change  DEXMXUS_daily_change  \
# Date
# 2022-05-02             -0.001513              0.640525              0.353652
# 2022-05-03              0.000000             -0.364794             -0.416034
# 2022-05-04              0.000000             -0.155800             -0.589797
# 2022-05-05              0.690083              0.249668              0.321369
# 2022-05-06              0.174344              0.319091             -0.887093
#
#             VIXCLS_daily_change  GVZCLS_daily_change  oil_daily_changes  \
# Date
# 2022-05-02            -3.173653             1.159859           0.458492
# 2022-05-03            -9.554731            -1.744766          -2.624317
# 2022-05-04           -13.094017            -4.566210           5.272916
# 2022-05-05            22.738002             2.923977           0.417405
# 2022-05-06            -3.237179            -3.357438           1.394785
#
#             Lag 1_Returns  Lag 2_Returns
# Date
# 2022-05-02      -3.628451       2.474690
# 2022-05-03       0.567524      -3.628451
# 2022-05-04       0.483713       0.567524
# 2022-05-05       2.986242       0.483713
# 2022-05-06      -3.564971       2.986242
#
# [5 rows x 35 columns]

# %%
Y_train_LSTM.head()
# Out:
# Date
# 2014-04-30    0
# 2014-05-01    0
# 2014-05-02    1
# 2014-05-05    0
# 2014-05-06    1
# Name: TARGET, dtype: int32

# %%
Y_test_LSTM.head()
# Out:
# Date
# 2022-05-02    1
# 2022-05-03    1
# 2022-05-04    0
# 2022-05-05    0
# 2022-05-06    0
# Name: TARGET, dtype: int32

# %% [markdown]
# Definición del Modelo LSTM

# %%
## Function to define the LSTM arquitecture. Source: King's College London: Dr. Ilias Chronopoulos
def model_fn(params):
    # Crear generadores de series temporales
    train_generator = TimeseriesGenerator(X_train_scaled_LSTM, Y_train_LSTM.values,
                                          length=14, batch_size=params["batch_size"])
    val_generator = TimeseriesGenerator(X_test_scaled_LSTM, Y_test_LSTM.values,
                                        length=14, batch_size=params["batch_size"])
    test_generator = TimeseriesGenerator(X_test_scaled_LSTM, Y_test_LSTM.values,
                                         length=14, batch_size=params["batch_size"]
                                    )
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.LSTM(int(params["lstm_size"]), input_shape=(14, X_train_scaled_LSTM.shape[1]),
                                   return_sequences=True if params["num_layers"] > 1 else False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(params["dropout"]))

    if params["num_layers"] == 2:
        model.add(tf.keras.layers.LSTM(int(params["lstm_size"])))
        model.add(tf.keras.layers.BatchNormalization())
        model.add(tf.keras.layers.Dropout(params["dropout"]))

    model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
    
    model.compile(optimizer=tf.keras.optimizers.Adam(params["learning_rate"]),
                  loss="binary_crossentropy", metrics=["accuracy"])

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True)]
    
    history = model.fit(train_generator, validation_data=val_generator,
                        callbacks=callbacks, epochs=100, verbose=0).history
    
    return (history, model)

# %% [markdown]
# Búsqueda Aleatoria de Hiperparámetros

# %%
# Set the random seed to get reproducible outcomes, e.g. when running model using six covariates, or only two covariates
tf.random.set_seed(42)
np.random.seed(42)
import random
random.seed(42)

# %%
import os
import random

def random_search(model_fn, search_space, n_iter, search_dir):
    results = []
    histories = []
    
    if not os.path.exists(search_dir):
        os.mkdir(search_dir)
    
    best_model_path = os.path.join(search_dir, "best_model.h5")
    results_path = os.path.join(search_dir, "results.csv")
    
    for i in range(n_iter):
        params = {k: v[np.random.randint(len(v))] for k, v in search_space.items()}
        history, model = model_fn(params)
        
        histories.append(history)
        
        epochs = np.argmax(history["val_accuracy"]) + 1
        result = {k: v[epochs - 1] for k, v in history.items()}
        params["epochs"] = epochs
        
        if i == 0:
            best_val_acc = result["val_accuracy"]
            model.save(best_model_path)
        
        if result["val_accuracy"] > best_val_acc:
            best_val_acc = result["val_accuracy"]
            model.save(best_model_path)
        
        result = {**params, **result}
        results.append(result)
        tf.keras.backend.clear_session()
        print(f"iteration {i + 1} – {', '.join(f'{k}:{v:.4g}' for k, v in result.items())}")
    
    best_model = tf.keras.models.load_model(best_model_path)
    results = pd.DataFrame(results)
    results.to_csv(results_path, index=False)
    
    return (results, best_model, histories)

# %%
search_space = {
    "lstm_size": np.linspace(20, 200, 5, dtype=int),
    "dropout": np.linspace(0, 0.4, 5),
    "learning_rate": np.linspace(0.004, 0.01, 5),
    "num_layers": [1, 2],
    "batch_size": [16, 32, 64]
}

# %%
iterations = 150
results, best_model, all_histories = random_search(model_fn, search_space, iterations, "search_new
                                                   _v9")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# iteration 1 – lstm_size:200, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:64, epochs:6, accuracy:0.5457, loss:0.7033, val_accuracy:0.5135, val_loss:0.7147
# iteration 2 – lstm_size:155, dropout:0.2, learning_rate:0.004, num_layers:2, batch_size:16, epochs:2, accuracy:0.531, loss:0.727, val_accuracy:0.5114, val_loss:0.9371
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# iteration 3 – lstm_size:155, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:16, epochs:1, accuracy:0.5284, loss:0.8381, val_accuracy:0.5155, val_loss:0.7197
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# iteration 4 – lstm_size:110, dropout:0.3, learning_rate:0.004, num_layers:1, batch_size:16, epochs:1, accuracy:0.5401, loss:0.8232, val_accuracy:0.5238, val_loss:0.7391
# iteration 5 – lstm_size:20, dropout:0.4, learning_rate:0.007, num_layers:2, batch_size:16, epochs:2, accuracy:0.5528, loss:0.6932, val_accuracy:0.4969, val_loss:0.7339
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# iteration 6 – lstm_size:155, dropout:0.4, learning_rate:0.01, num_layers:2, batch_size:64, epochs:17, accuracy:0.5655, loss:0.6791, val_accuracy:0.53, val_loss:0.6976
# iteration 7 – lstm_size:20, dropout:0.2, learning_rate:0.0055, num_layers:1, batch_size:32, epochs:2, accuracy:0.5716, loss:0.6814, val_accuracy:0.5072, val_loss:0.7134
# iteration 8 – lstm_size:65, dropout:0.2, learning_rate:0.0055, num_layers:2, batch_size:64, epochs:3, accuracy:0.5939, loss:0.6763, val_accuracy:0.528, val_loss:0.7004
# iteration 9 – lstm_size:65, dropout:0.2, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:8, accuracy:0.7061, loss:0.5694, val_accuracy:0.5238, val_loss:0.8033
# iteration 10 – lstm_size:20, dropout:0, learning_rate:0.004, num_layers:1, batch_size:32, epochs:6, accuracy:0.7112, loss:0.5584, val_accuracy:0.5052, val_loss:1.058
# iteration 11 – lstm_size:200, dropout:0.1, learning_rate:0.0055, num_layers:1, batch_size:32, epochs:1, accuracy:0.5208, loss:0.8859, val_accuracy:0.5114, val_loss:0.7661
# iteration 12 – lstm_size:20, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:3, accuracy:0.5558, loss:0.687, val_accuracy:0.5176, val_loss:0.6978
# iteration 13 – lstm_size:20, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:16, epochs:1, accuracy:0.5244, loss:0.7434, val_accuracy:0.5031, val_loss:0.6967
# iteration 14 – lstm_size:155, dropout:0.2, learning_rate:0.0085, num_layers:2, batch_size:32, epochs:2, accuracy:0.5142, loss:0.7339, val_accuracy:0.5072, val_loss:0.7625
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# iteration 15 – lstm_size:110, dropout:0, learning_rate:0.0055, num_layers:1, batch_size:32, epochs:14, accuracy:0.9741, loss:0.08689, val_accuracy:0.5528, val_loss:1.679
# iteration 16 – lstm_size:200, dropout:0.1, learning_rate:0.0055, num_layers:2, batch_size:16, epochs:3, accuracy:0.5355, loss:0.7087, val_accuracy:0.5155, val_loss:0.6962
# iteration 17 – lstm_size:155, dropout:0.1, learning_rate:0.007, num_layers:2, batch_size:16, epochs:3, accuracy:0.5411, loss:0.7091, val_accuracy:0.4969, val_loss:0.7238
# iteration 18 – lstm_size:20, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:3, accuracy:0.5751, loss:0.6794, val_accuracy:0.5052, val_loss:0.7564
# iteration 19 – lstm_size:155, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:8, accuracy:0.5492, loss:0.6973, val_accuracy:0.5404, val_loss:0.7064
# iteration 20 – lstm_size:110, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:32, epochs:2, accuracy:0.5457, loss:0.6974, val_accuracy:0.5197, val_loss:0.6922
# iteration 21 – lstm_size:110, dropout:0, learning_rate:0.007, num_layers:2, batch_size:32, epochs:9, accuracy:0.6472, loss:0.6341, val_accuracy:0.5487, val_loss:0.7609
# iteration 22 – lstm_size:65, dropout:0.4, learning_rate:0.0055, num_layers:1, batch_size:32, epochs:11, accuracy:0.7457, loss:0.5081, val_accuracy:0.528, val_loss:1.219
# iteration 23 – lstm_size:20, dropout:0.3, learning_rate:0.01, num_layers:1, batch_size:32, epochs:21, accuracy:0.8335, loss:0.3922, val_accuracy:0.5424, val_loss:1.342
# iteration 24 – lstm_size:65, dropout:0, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:7, accuracy:0.7675, loss:0.4805, val_accuracy:0.5362, val_loss:0.9436
# iteration 25 – lstm_size:20, dropout:0.4, learning_rate:0.01, num_layers:1, batch_size:16, epochs:6, accuracy:0.6299, loss:0.6408, val_accuracy:0.5114, val_loss:0.8471
# iteration 26 – lstm_size:200, dropout:0.4, learning_rate:0.007, num_layers:2, batch_size:32, epochs:7, accuracy:0.5563, loss:0.6978, val_accuracy:0.5176, val_loss:0.695
# iteration 27 – lstm_size:110, dropout:0.4, learning_rate:0.004, num_layers:1, batch_size:32, epochs:4, accuracy:0.6269, loss:0.6386, val_accuracy:0.5238, val_loss:0.7374
# iteration 28 – lstm_size:155, dropout:0.4, learning_rate:0.004, num_layers:2, batch_size:32, epochs:4, accuracy:0.5472, loss:0.6935, val_accuracy:0.5445, val_loss:0.6956
# iteration 29 – lstm_size:155, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:32, epochs:3, accuracy:0.535, loss:0.7174, val_accuracy:0.5176, val_loss:0.7109
# iteration 30 – lstm_size:65, dropout:0.4, learning_rate:0.0085, num_layers:1, batch_size:32, epochs:9, accuracy:0.7198, loss:0.5524, val_accuracy:0.5424, val_loss:0.8606
# iteration 31 – lstm_size:200, dropout:0.1, learning_rate:0.0055, num_layers:2, batch_size:16, epochs:7, accuracy:0.5787, loss:0.6817, val_accuracy:0.5155, val_loss:0.796
# iteration 32 – lstm_size:155, dropout:0.1, learning_rate:0.0085, num_layers:1, batch_size:32, epochs:1, accuracy:0.532, loss:0.8536, val_accuracy:0.5238, val_loss:0.6939
# iteration 33 – lstm_size:65, dropout:0.2, learning_rate:0.0055, num_layers:2, batch_size:16, epochs:12, accuracy:0.7629, loss:0.4912, val_accuracy:0.5383, val_loss:0.9595
# iteration 34 – lstm_size:200, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:2, accuracy:0.5081, loss:0.7621, val_accuracy:0.5135, val_loss:0.6959
# iteration 35 – lstm_size:65, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:7, accuracy:0.7604, loss:0.4848, val_accuracy:0.5259, val_loss:0.8374
# iteration 36 – lstm_size:155, dropout:0.3, learning_rate:0.0055, num_layers:1, batch_size:16, epochs:2, accuracy:0.5731, loss:0.6954, val_accuracy:0.5155, val_loss:0.781
# iteration 37 – lstm_size:20, dropout:0.4, learning_rate:0.007, num_layers:1, batch_size:16, epochs:3, accuracy:0.5914, loss:0.6701, val_accuracy:0.5031, val_loss:0.7389
# iteration 38 – lstm_size:155, dropout:0.2, learning_rate:0.004, num_layers:1, batch_size:32, epochs:2, accuracy:0.5812, loss:0.6974, val_accuracy:0.5362, val_loss:0.7152
# iteration 39 – lstm_size:110, dropout:0.3, learning_rate:0.01, num_layers:1, batch_size:64, epochs:2, accuracy:0.5569, loss:0.6955, val_accuracy:0.5155, val_loss:0.7077
# iteration 40 – lstm_size:65, dropout:0.4, learning_rate:0.007, num_layers:2, batch_size:64, epochs:4, accuracy:0.5726, loss:0.6808, val_accuracy:0.528, val_loss:0.6934
# iteration 41 – lstm_size:20, dropout:0.1, learning_rate:0.01, num_layers:2, batch_size:32, epochs:8, accuracy:0.6706, loss:0.6, val_accuracy:0.5362, val_loss:0.8473
# iteration 42 – lstm_size:65, dropout:0.1, learning_rate:0.007, num_layers:1, batch_size:64, epochs:8, accuracy:0.765, loss:0.4793, val_accuracy:0.5466, val_loss:0.7793
# iteration 43 – lstm_size:155, dropout:0.1, learning_rate:0.01, num_layers:2, batch_size:16, epochs:3, accuracy:0.5208, loss:0.7108, val_accuracy:0.5093, val_loss:0.7184
# iteration 44 – lstm_size:110, dropout:0.4, learning_rate:0.0085, num_layers:1, batch_size:16, epochs:4, accuracy:0.5751, loss:0.6905, val_accuracy:0.5259, val_loss:0.6972
# iteration 45 – lstm_size:200, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:3, accuracy:0.5198, loss:0.7168, val_accuracy:0.5135, val_loss:0.7089
# iteration 46 – lstm_size:20, dropout:0.2, learning_rate:0.004, num_layers:1, batch_size:32, epochs:7, accuracy:0.6812, loss:0.5914, val_accuracy:0.5445, val_loss:0.7919
# iteration 47 – lstm_size:20, dropout:0.4, learning_rate:0.0085, num_layers:1, batch_size:64, epochs:5, accuracy:0.6299, loss:0.6483, val_accuracy:0.5052, val_loss:0.7082
# iteration 48 – lstm_size:200, dropout:0, learning_rate:0.007, num_layers:1, batch_size:32, epochs:4, accuracy:0.5675, loss:0.6843, val_accuracy:0.5197, val_loss:0.7264
# iteration 49 – lstm_size:20, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:12, accuracy:0.8218, loss:0.393, val_accuracy:0.5528, val_loss:1.019
# iteration 50 – lstm_size:200, dropout:0.2, learning_rate:0.007, num_layers:1, batch_size:16, epochs:5, accuracy:0.5706, loss:0.6969, val_accuracy:0.5135, val_loss:0.9199
# iteration 51 – lstm_size:20, dropout:0.2, learning_rate:0.0085, num_layers:1, batch_size:64, epochs:3, accuracy:0.5883, loss:0.6641, val_accuracy:0.5176, val_loss:0.7007
# iteration 52 – lstm_size:155, dropout:0.3, learning_rate:0.007, num_layers:2, batch_size:64, epochs:3, accuracy:0.5345, loss:0.714, val_accuracy:0.501, val_loss:0.6972
# iteration 53 – lstm_size:200, dropout:0.4, learning_rate:0.007, num_layers:2, batch_size:16, epochs:1, accuracy:0.5315, loss:0.854, val_accuracy:0.5197, val_loss:0.7384
# iteration 54 – lstm_size:155, dropout:0.2, learning_rate:0.01, num_layers:2, batch_size:16, epochs:7, accuracy:0.5675, loss:0.6872, val_accuracy:0.5259, val_loss:0.6976
# iteration 55 – lstm_size:20, dropout:0.4, learning_rate:0.01, num_layers:2, batch_size:32, epochs:12, accuracy:0.6305, loss:0.6445, val_accuracy:0.5259, val_loss:0.8094
# iteration 56 – lstm_size:65, dropout:0.4, learning_rate:0.007, num_layers:1, batch_size:16, epochs:4, accuracy:0.6086, loss:0.6497, val_accuracy:0.5238, val_loss:0.8235
# iteration 57 – lstm_size:110, dropout:0.2, learning_rate:0.0055, num_layers:1, batch_size:16, epochs:7, accuracy:0.6751, loss:0.5974, val_accuracy:0.5383, val_loss:1.223
# iteration 58 – lstm_size:65, dropout:0.1, learning_rate:0.0085, num_layers:1, batch_size:16, epochs:11, accuracy:0.8406, loss:0.3595, val_accuracy:0.5445, val_loss:1.867
# iteration 59 – lstm_size:200, dropout:0.1, learning_rate:0.004, num_layers:2, batch_size:64, epochs:6, accuracy:0.5553, loss:0.6902, val_accuracy:0.5342, val_loss:0.695
# iteration 60 – lstm_size:65, dropout:0.1, learning_rate:0.01, num_layers:1, batch_size:16, epochs:12, accuracy:0.7401, loss:0.5105, val_accuracy:0.5238, val_loss:1.511
# iteration 61 – lstm_size:110, dropout:0.4, learning_rate:0.004, num_layers:2, batch_size:16, epochs:9, accuracy:0.6386, loss:0.6444, val_accuracy:0.53, val_loss:0.7665
# iteration 62 – lstm_size:20, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:32, epochs:2, accuracy:0.5381, loss:0.6939, val_accuracy:0.5093, val_loss:0.6965
# iteration 63 – lstm_size:155, dropout:0.2, learning_rate:0.01, num_layers:2, batch_size:32, epochs:5, accuracy:0.5447, loss:0.6994, val_accuracy:0.5197, val_loss:0.6983
# iteration 64 – lstm_size:110, dropout:0.1, learning_rate:0.0055, num_layers:1, batch_size:64, epochs:2, accuracy:0.5523, loss:0.7078, val_accuracy:0.5383, val_loss:0.6986
# iteration 65 – lstm_size:110, dropout:0.4, learning_rate:0.01, num_layers:2, batch_size:32, epochs:1, accuracy:0.5041, loss:0.8239, val_accuracy:0.5217, val_loss:0.6955
# iteration 66 – lstm_size:65, dropout:0.3, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:8, accuracy:0.5975, loss:0.6636, val_accuracy:0.5342, val_loss:0.7637
# iteration 67 – lstm_size:20, dropout:0, learning_rate:0.007, num_layers:1, batch_size:32, epochs:9, accuracy:0.8, loss:0.4296, val_accuracy:0.5197, val_loss:1.34
# iteration 68 – lstm_size:20, dropout:0.3, learning_rate:0.004, num_layers:1, batch_size:16, epochs:4, accuracy:0.6178, loss:0.6458, val_accuracy:0.5404, val_loss:0.7809
# iteration 69 – lstm_size:200, dropout:0.1, learning_rate:0.0085, num_layers:1, batch_size:16, epochs:1, accuracy:0.5431, loss:0.8098, val_accuracy:0.5052, val_loss:0.6951
# iteration 70 – lstm_size:200, dropout:0.4, learning_rate:0.01, num_layers:1, batch_size:16, epochs:1, accuracy:0.5239, loss:0.8446, val_accuracy:0.5072, val_loss:0.749
# iteration 71 – lstm_size:155, dropout:0.2, learning_rate:0.007, num_layers:2, batch_size:16, epochs:6, accuracy:0.5807, loss:0.6777, val_accuracy:0.53, val_loss:0.8564
# iteration 72 – lstm_size:65, dropout:0, learning_rate:0.004, num_layers:2, batch_size:64, epochs:17, accuracy:0.9914, loss:0.03847, val_accuracy:0.5259, val_loss:1.917
# iteration 73 – lstm_size:20, dropout:0.4, learning_rate:0.007, num_layers:2, batch_size:64, epochs:1, accuracy:0.5152, loss:0.8136, val_accuracy:0.501, val_loss:0.6986
# iteration 74 – lstm_size:20, dropout:0.2, learning_rate:0.0085, num_layers:2, batch_size:32, epochs:3, accuracy:0.5904, loss:0.6647, val_accuracy:0.5031, val_loss:0.7093
# iteration 75 – lstm_size:155, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:32, epochs:5, accuracy:0.5168, loss:0.7024, val_accuracy:0.5155, val_loss:0.698
# iteration 76 – lstm_size:155, dropout:0.3, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:4, accuracy:0.5345, loss:0.6904, val_accuracy:0.5114, val_loss:0.8018
# iteration 77 – lstm_size:155, dropout:0.1, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:1, accuracy:0.5264, loss:0.8016, val_accuracy:0.5155, val_loss:0.6941
# iteration 78 – lstm_size:20, dropout:0.3, learning_rate:0.007, num_layers:2, batch_size:64, epochs:3, accuracy:0.5482, loss:0.691, val_accuracy:0.5072, val_loss:0.7024
# iteration 79 – lstm_size:20, dropout:0, learning_rate:0.004, num_layers:1, batch_size:16, epochs:17, accuracy:0.9228, loss:0.2124, val_accuracy:0.5217, val_loss:2.216
# iteration 80 – lstm_size:155, dropout:0.4, learning_rate:0.01, num_layers:2, batch_size:64, epochs:6, accuracy:0.5213, loss:0.712, val_accuracy:0.5238, val_loss:0.7131
# iteration 81 – lstm_size:200, dropout:0.1, learning_rate:0.007, num_layers:2, batch_size:16, epochs:7, accuracy:0.5538, loss:0.6987, val_accuracy:0.5404, val_loss:0.7069
# iteration 82 – lstm_size:20, dropout:0.1, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:7, accuracy:0.6807, loss:0.5937, val_accuracy:0.528, val_loss:0.8023
# iteration 83 – lstm_size:65, dropout:0.2, learning_rate:0.01, num_layers:1, batch_size:64, epochs:4, accuracy:0.6523, loss:0.6298, val_accuracy:0.5487, val_loss:0.6941
# iteration 84 – lstm_size:20, dropout:0, learning_rate:0.0055, num_layers:2, batch_size:64, epochs:2, accuracy:0.6076, loss:0.6677, val_accuracy:0.53, val_loss:0.6977
# iteration 85 – lstm_size:20, dropout:0.2, learning_rate:0.01, num_layers:2, batch_size:64, epochs:3, accuracy:0.5665, loss:0.6818, val_accuracy:0.5072, val_loss:0.6981
# iteration 86 – lstm_size:20, dropout:0.2, learning_rate:0.007, num_layers:1, batch_size:16, epochs:1, accuracy:0.5371, loss:0.7779, val_accuracy:0.5197, val_loss:0.7084
# iteration 87 – lstm_size:20, dropout:0.1, learning_rate:0.004, num_layers:1, batch_size:64, epochs:7, accuracy:0.6853, loss:0.5919, val_accuracy:0.5072, val_loss:0.7723
# iteration 88 – lstm_size:20, dropout:0.4, learning_rate:0.0085, num_layers:1, batch_size:16, epochs:1, accuracy:0.536, loss:0.7539, val_accuracy:0.5031, val_loss:0.7046
# iteration 89 – lstm_size:200, dropout:0.2, learning_rate:0.01, num_layers:1, batch_size:16, epochs:3, accuracy:0.5371, loss:0.7233, val_accuracy:0.5197, val_loss:0.8331
# iteration 90 – lstm_size:200, dropout:0.4, learning_rate:0.0055, num_layers:2, batch_size:64, epochs:5, accuracy:0.5284, loss:0.7041, val_accuracy:0.5321, val_loss:0.6975
# iteration 91 – lstm_size:20, dropout:0.4, learning_rate:0.004, num_layers:2, batch_size:16, epochs:5, accuracy:0.5807, loss:0.6647, val_accuracy:0.5114, val_loss:0.7805
# iteration 92 – lstm_size:110, dropout:0.4, learning_rate:0.01, num_layers:2, batch_size:32, epochs:2, accuracy:0.532, loss:0.7067, val_accuracy:0.5052, val_loss:0.6975
# iteration 93 – lstm_size:20, dropout:0, learning_rate:0.0055, num_layers:2, batch_size:64, epochs:4, accuracy:0.6528, loss:0.6132, val_accuracy:0.5114, val_loss:0.698
# iteration 94 – lstm_size:65, dropout:0.1, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:13, accuracy:0.8508, loss:0.3286, val_accuracy:0.5487, val_loss:0.9939
# iteration 95 – lstm_size:110, dropout:0.2, learning_rate:0.0055, num_layers:2, batch_size:16, epochs:4, accuracy:0.5893, loss:0.6715, val_accuracy:0.5155, val_loss:1.176
# iteration 96 – lstm_size:155, dropout:0.4, learning_rate:0.007, num_layers:1, batch_size:16, epochs:2, accuracy:0.5472, loss:0.6997, val_accuracy:0.5424, val_loss:0.7131
# iteration 97 – lstm_size:200, dropout:0.4, learning_rate:0.0055, num_layers:1, batch_size:64, epochs:1, accuracy:0.5168, loss:0.881, val_accuracy:0.5093, val_loss:0.7041
# iteration 98 – lstm_size:155, dropout:0.1, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:3, accuracy:0.5239, loss:0.7126, val_accuracy:0.5342, val_loss:0.7059
# iteration 99 – lstm_size:110, dropout:0.2, learning_rate:0.0055, num_layers:2, batch_size:16, epochs:8, accuracy:0.5766, loss:0.6793, val_accuracy:0.528, val_loss:0.7642
# iteration 100 – lstm_size:20, dropout:0.3, learning_rate:0.0055, num_layers:1, batch_size:16, epochs:1, accuracy:0.5299, loss:0.7629, val_accuracy:0.5093, val_loss:0.7184
# iteration 101 – lstm_size:200, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:3, accuracy:0.5355, loss:0.6972, val_accuracy:0.5135, val_loss:0.7796
# iteration 102 – lstm_size:65, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:2, accuracy:0.567, loss:0.6781, val_accuracy:0.528, val_loss:0.7182
# iteration 103 – lstm_size:65, dropout:0.4, learning_rate:0.0055, num_layers:1, batch_size:32, epochs:4, accuracy:0.6173, loss:0.6422, val_accuracy:0.5114, val_loss:0.743
# iteration 104 – lstm_size:110, dropout:0.2, learning_rate:0.007, num_layers:1, batch_size:64, epochs:4, accuracy:0.6472, loss:0.6232, val_accuracy:0.53, val_loss:0.7097
# iteration 105 – lstm_size:20, dropout:0.2, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:14, accuracy:0.6792, loss:0.5905, val_accuracy:0.5342, val_loss:0.9707
# iteration 106 – lstm_size:110, dropout:0.2, learning_rate:0.007, num_layers:1, batch_size:32, epochs:9, accuracy:0.7492, loss:0.4894, val_accuracy:0.5259, val_loss:1.071
# iteration 107 – lstm_size:200, dropout:0.1, learning_rate:0.007, num_layers:1, batch_size:16, epochs:6, accuracy:0.5787, loss:0.6763, val_accuracy:0.5362, val_loss:0.7939
# iteration 108 – lstm_size:200, dropout:0.1, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:3, accuracy:0.5629, loss:0.6963, val_accuracy:0.5424, val_loss:0.7165
# iteration 109 – lstm_size:200, dropout:0, learning_rate:0.01, num_layers:1, batch_size:32, epochs:5, accuracy:0.5254, loss:0.7096, val_accuracy:0.5259, val_loss:0.7166
# iteration 110 – lstm_size:65, dropout:0, learning_rate:0.0055, num_layers:1, batch_size:64, epochs:4, accuracy:0.6934, loss:0.5736, val_accuracy:0.5052, val_loss:0.7294
# iteration 111 – lstm_size:20, dropout:0.1, learning_rate:0.004, num_layers:1, batch_size:16, epochs:5, accuracy:0.6695, loss:0.5921, val_accuracy:0.528, val_loss:0.9376
# iteration 112 – lstm_size:110, dropout:0.4, learning_rate:0.004, num_layers:2, batch_size:16, epochs:10, accuracy:0.597, loss:0.6676, val_accuracy:0.5404, val_loss:0.8038
# iteration 113 – lstm_size:20, dropout:0.2, learning_rate:0.01, num_layers:2, batch_size:64, epochs:1, accuracy:0.5259, loss:0.7891, val_accuracy:0.501, val_loss:0.7014
# iteration 114 – lstm_size:65, dropout:0.3, learning_rate:0.0055, num_layers:1, batch_size:32, epochs:5, accuracy:0.6599, loss:0.6171, val_accuracy:0.5362, val_loss:0.7623
# iteration 115 – lstm_size:110, dropout:0.2, learning_rate:0.007, num_layers:1, batch_size:64, epochs:1, accuracy:0.5193, loss:0.8821, val_accuracy:0.5445, val_loss:0.6946
# iteration 116 – lstm_size:110, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:32, epochs:7, accuracy:0.5543, loss:0.6918, val_accuracy:0.5383, val_loss:0.6939
# iteration 117 – lstm_size:110, dropout:0.2, learning_rate:0.004, num_layers:1, batch_size:16, epochs:3, accuracy:0.6284, loss:0.6412, val_accuracy:0.5321, val_loss:0.8531
# iteration 118 – lstm_size:155, dropout:0.1, learning_rate:0.004, num_layers:1, batch_size:64, epochs:2, accuracy:0.5873, loss:0.6925, val_accuracy:0.5197, val_loss:0.7181
# iteration 119 – lstm_size:65, dropout:0.3, learning_rate:0.004, num_layers:1, batch_size:16, epochs:3, accuracy:0.6386, loss:0.6473, val_accuracy:0.5197, val_loss:1.003
# iteration 120 – lstm_size:155, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:2, accuracy:0.5299, loss:0.7071, val_accuracy:0.5342, val_loss:0.694
# iteration 121 – lstm_size:20, dropout:0.4, learning_rate:0.0055, num_layers:1, batch_size:64, epochs:5, accuracy:0.5924, loss:0.6682, val_accuracy:0.4886, val_loss:0.7193
# iteration 122 – lstm_size:65, dropout:0, learning_rate:0.0085, num_layers:1, batch_size:32, epochs:20, accuracy:0.9614, loss:0.1002, val_accuracy:0.5445, val_loss:2.392
# iteration 123 – lstm_size:20, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:32, epochs:1, accuracy:0.535, loss:0.797, val_accuracy:0.501, val_loss:0.7027
# iteration 124 – lstm_size:110, dropout:0.2, learning_rate:0.01, num_layers:2, batch_size:16, epochs:8, accuracy:0.5569, loss:0.6922, val_accuracy:0.5114, val_loss:0.8326
# iteration 125 – lstm_size:20, dropout:0, learning_rate:0.01, num_layers:2, batch_size:16, epochs:3, accuracy:0.6396, loss:0.6349, val_accuracy:0.5445, val_loss:0.7378
# iteration 126 – lstm_size:155, dropout:0.2, learning_rate:0.004, num_layers:1, batch_size:64, epochs:1, accuracy:0.5041, loss:0.8775, val_accuracy:0.5135, val_loss:0.7104
# iteration 127 – lstm_size:110, dropout:0.4, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:9, accuracy:0.603, loss:0.6644, val_accuracy:0.5155, val_loss:0.7181
# iteration 128 – lstm_size:65, dropout:0.3, learning_rate:0.0085, num_layers:1, batch_size:64, epochs:3, accuracy:0.6015, loss:0.6618, val_accuracy:0.5155, val_loss:0.7196
# iteration 129 – lstm_size:20, dropout:0.2, learning_rate:0.004, num_layers:2, batch_size:64, epochs:1, accuracy:0.5198, loss:0.7768, val_accuracy:0.501, val_loss:0.7016
# iteration 130 – lstm_size:110, dropout:0.1, learning_rate:0.007, num_layers:1, batch_size:16, epochs:9, accuracy:0.7558, loss:0.4983, val_accuracy:0.5528, val_loss:1.103
# iteration 131 – lstm_size:65, dropout:0.3, learning_rate:0.007, num_layers:2, batch_size:16, epochs:4, accuracy:0.5934, loss:0.6682, val_accuracy:0.5176, val_loss:0.7732
# iteration 132 – lstm_size:155, dropout:0, learning_rate:0.0085, num_layers:1, batch_size:16, epochs:8, accuracy:0.5959, loss:0.6626, val_accuracy:0.5217, val_loss:0.8207
# iteration 133 – lstm_size:65, dropout:0.4, learning_rate:0.007, num_layers:1, batch_size:16, epochs:12, accuracy:0.7528, loss:0.4934, val_accuracy:0.528, val_loss:1.306
# iteration 134 – lstm_size:110, dropout:0.2, learning_rate:0.004, num_layers:2, batch_size:32, epochs:6, accuracy:0.5675, loss:0.6811, val_accuracy:0.5114, val_loss:0.701
# iteration 135 – lstm_size:65, dropout:0.4, learning_rate:0.0055, num_layers:2, batch_size:32, epochs:2, accuracy:0.5437, loss:0.7118, val_accuracy:0.5176, val_loss:0.7198
# iteration 136 – lstm_size:200, dropout:0.1, learning_rate:0.0085, num_layers:1, batch_size:64, epochs:11, accuracy:0.633, loss:0.643, val_accuracy:0.5445, val_loss:0.7436
# iteration 137 – lstm_size:200, dropout:0, learning_rate:0.004, num_layers:1, batch_size:64, epochs:5, accuracy:0.7122, loss:0.5575, val_accuracy:0.5238, val_loss:0.7314
# iteration 138 – lstm_size:110, dropout:0, learning_rate:0.01, num_layers:2, batch_size:32, epochs:5, accuracy:0.5523, loss:0.6889, val_accuracy:0.5424, val_loss:0.6929
# iteration 139 – lstm_size:200, dropout:0.2, learning_rate:0.004, num_layers:2, batch_size:64, epochs:4, accuracy:0.5168, loss:0.745, val_accuracy:0.5155, val_loss:0.694
# iteration 140 – lstm_size:110, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:16, epochs:1, accuracy:0.5325, loss:0.8025, val_accuracy:0.5031, val_loss:0.6998
# iteration 141 – lstm_size:110, dropout:0, learning_rate:0.01, num_layers:2, batch_size:32, epochs:1, accuracy:0.5015, loss:0.8707, val_accuracy:0.528, val_loss:0.6929
# iteration 142 – lstm_size:110, dropout:0.4, learning_rate:0.01, num_layers:1, batch_size:64, epochs:12, accuracy:0.6553, loss:0.6108, val_accuracy:0.5238, val_loss:0.7522
# iteration 143 – lstm_size:110, dropout:0.1, learning_rate:0.0085, num_layers:1, batch_size:16, epochs:10, accuracy:0.7335, loss:0.5141, val_accuracy:0.5445, val_loss:1.19
# iteration 144 – lstm_size:65, dropout:0, learning_rate:0.0055, num_layers:2, batch_size:64, epochs:4, accuracy:0.6355, loss:0.6353, val_accuracy:0.53, val_loss:0.71
# iteration 145 – lstm_size:110, dropout:0.4, learning_rate:0.004, num_layers:1, batch_size:64, epochs:4, accuracy:0.5853, loss:0.6834, val_accuracy:0.5093, val_loss:0.697
# iteration 146 – lstm_size:20, dropout:0, learning_rate:0.004, num_layers:1, batch_size:64, epochs:8, accuracy:0.735, loss:0.5356, val_accuracy:0.5259, val_loss:0.8115
# iteration 147 – lstm_size:65, dropout:0.4, learning_rate:0.007, num_layers:1, batch_size:64, epochs:2, accuracy:0.5584, loss:0.7042, val_accuracy:0.5321, val_loss:0.6954
# iteration 148 – lstm_size:110, dropout:0.2, learning_rate:0.0055, num_layers:2, batch_size:64, epochs:5, accuracy:0.5863, loss:0.6825, val_accuracy:0.5259, val_loss:0.7242
# iteration 149 – lstm_size:200, dropout:0, learning_rate:0.0085, num_layers:2, batch_size:64, epochs:8, accuracy:0.5741, loss:0.6698, val_accuracy:0.5217, val_loss:0.7521
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# iteration 150 – lstm_size:110, dropout:0.3, learning_rate:0.01, num_layers:2, batch_size:16, epochs:1, accuracy:0.5269, loss:0.7834, val_accuracy:0.5135, val_loss:0.6993

# %%
# Sort the results by validation accuracy in descending order
sorted_results = results.sort_values("val_accuracy", ascending=False)

# Extract the best batch_size as it is needed to recreate the "test_generator"
# Note that the test generator in this script is within the function "model_fn", whcih cannot be recalled later
# Therefore, we need to recreate it later. 

best_batch_size = sorted_results.iloc[0]['batch_size']

# Recreate the test_generator using the best batch_size
test_generator = TimeseriesGenerator(X_test_scaled_LSTM, Y_test_LSTM.values,
                                     length=14, batch_size=int(best_batch_size),  
                                     )

# Then evaluate the best model
best_model.evaluate(test_generator)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5532 - loss: 1.9355
# [1.6788411140441895, 0.5527950525283813]

# %%
# Show the results of hyperparamter tuning
results.sort_values("val_accuracy", ascending = False)
# Out:
#      lstm_size  dropout  learning_rate  num_layers  batch_size  epochs  \
# 14         110      0.0         0.0055           1          32      14
# 129        110      0.1         0.0070           1          16       9
# 48          20      0.0         0.0085           2          16      12
# 93          65      0.1         0.0055           2          32      13
# 82          65      0.2         0.0100           1          64       4
# ..         ...      ...            ...         ...         ...     ...
# 122         20      0.4         0.0085           2          32       1
# 128         20      0.2         0.0040           2          64       1
# 16         155      0.1         0.0070           2          16       3
# 4           20      0.4         0.0070           2          16       2
# 120         20      0.4         0.0055           1          64       5
#
#      accuracy      loss  val_accuracy  val_loss
# 14   0.974112  0.086890      0.552795  1.678841
# 129  0.755838  0.498277      0.552795  1.102703
# 48   0.821827  0.392993      0.552795  1.019050
# 93   0.850761  0.328604      0.548654  0.993860
# 82   0.652284  0.629825      0.548654  0.694103
# ..        ...       ...           ...       ...
# 122  0.535025  0.796979      0.501035  0.702727
# 128  0.519797  0.776794      0.501035  0.701622
# 16   0.541117  0.709148      0.496894  0.723815
# 4    0.552792  0.693188      0.496894  0.733865
# 120  0.592386  0.668208      0.488613  0.719310
#
# [150 rows x 10 columns]

# %%
# Show the architecture of the optimised LSTM model
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 110)            │        64,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 110)            │           440 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 110)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           111 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 64,793 (253.10 KB)
#  Trainable params: 64,571 (252.23 KB)
#  Non-trainable params: 220 (880.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# Evaluar el mejor modelo
best_model.evaluate(test_generator)

# Obtener predicciones del mejor modelo
predictions = best_model.predict(test_generator)

# Aplicar el umbral para convertir las predicciones a 0 y 1
predictions_binary = (predictions > 0.5).astype(int)

# Ajustar la longitud de Y_test_LSTM para que coincida con las predicciones
Y_test_adjusted = Y_test_LSTM[14:].values

# Crear un DataFrame para comparar predicciones y valores reales
results_df = pd.DataFrame({
    'Fecha': Y_test_LSTM.index[14:],  # Ajustar la longitud del índice
    'Valor_Real': Y_test_adjusted,
    'Predicción': predictions_binary.flatten()
})

# Guardar los resultados en un archivo CSV
filename = f'LTSM_opt_forecast_results_{fecha_inicio}_{test_size_Control}.csv'
results_df.to_csv(filename, index=False)

# Mostrar los resultados
print(results_df)

# Graficar los resultados
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(results_df['Fecha'], results_df['Valor_Real'], label='Valor Real')
plt.plot(results_df['Fecha'], results_df['Predicción'], label='Predicción', color='red')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.title('Comparación de Valores Reales y Predicciones')
plt.legend()
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5532 - loss: 1.9355
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#          Fecha  Valor_Real  Predicción
# 0   2022-05-20           1           1
# 1   2022-05-23           0           1
# 2   2022-05-24           1           1
# 3   2022-05-25           1           1
# 4   2022-05-26           1           1
# ..         ...         ...         ...
# 478 2024-04-24           0           1
# 479 2024-04-25           1           1
# 480 2024-04-26           1           0
# 481 2024-04-29           0           1
# 482 2024-04-30           0           1
#
# [483 rows x 3 columns]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calcula la matriz de confusión usando las predicciones ajustadas y los valores reales
conf_matrix = confusion_matrix(Y_test_adjusted, predictions_binary)

# Visualiza la matriz de confusión con Seaborn para una representación más clara
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicciones')
plt.ylabel('Valores Reales')
plt.title('Matriz de Confusión')
plt.xticks([0.5, 1.5], ['Negativo (0)', 'Positivo (1)'], rotation=0)
plt.yticks([0.5, 1.5], ['Negativo (0)', 'Positivo (1)'], rotation=0, va='center')
plt.show()

# %%
# Asumiendo que 'results_df' ya está definido y contiene las columnas 'Valor_Real' y 'Predicción'

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(results_df['Valor_Real'], results_df['Predicción'])

# Calcular métricas de desempeño
accuracy = accuracy_score(results_df['Valor_Real'], results_df['Predicción'])
precision = precision_score(results_df['Valor_Real'], results_df['Predicción'])
recall = recall_score(results_df['Valor_Real'], results_df['Predicción'])
f1 = f1_score(results_df['Valor_Real'], results_df['Predicción'])

# Imprimir los resultados
print("Matriz de Confusión:")
print(conf_matrix)
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall (Sensibilidad): {recall:.4f}")
print(f"F1-Score: {f1:.4f}")

# Opcional: Calcular la especificidad
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
specificity = TN / (TN + FP)
print(f"Especificidad: {specificity:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Asumiendo que 'results_df' ya está definido y contiene las columnas 'Valor_Real' y 'Predicción'
#       2
#       3 # Calcular la matriz de confusión
# ----> 4 conf_matrix = confusion_matrix(results_df['Valor_Real'], results_df['Predicción'])
#       6 # Calcular métricas de desempeño
#       7 accuracy = accuracy_score(results_df['Valor_Real'], results_df['Predicción'])
#
# NameError: name 'confusion_matrix' is not defined
